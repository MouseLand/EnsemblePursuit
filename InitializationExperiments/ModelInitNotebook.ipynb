# %%
from InitModelPipeline import ModelPipeline

# %%
data_path='/home/maria/Documents/EnsemblePursuit/SAND9/data/'
save_path='/home/maria/Documents/EnsemblePursuit/SAND9/experiments/'

# %%
EP_model_thresh=ModelPipeline(data_path=data_path, save_path=save_path, model='EnsemblePursuit_tfidf',nr_of_components=150,lambd_=0.01)
EP_model_thresh.fit_model()
# Out:
# natimg2800_M170717_MP034_2017-09-11.mat
# /home/maria/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:138: RuntimeWarning: invalid value encountered in sqrt
#   ret = um.sqrt(ret, out=ret)
# ensemble nr 0
# cost tensor(0.9939, device='cuda:0')
# ensemble nr 1
# cost tensor(0.9915, device='cuda:0')
# ensemble nr 2
# cost tensor(0.9898, device='cuda:0')
# ensemble nr 3
# cost tensor(0.9852, device='cuda:0')
# ensemble nr 4
# cost tensor(0.9829, device='cuda:0')
# ensemble nr 5
# cost tensor(0.9793, device='cuda:0')
# ensemble nr 6
# cost tensor(0.9772, device='cuda:0')
# ensemble nr 7
# cost tensor(0.9756, device='cuda:0')
# ensemble nr 8
# cost tensor(0.9741, device='cuda:0')
# ensemble nr 9
# cost tensor(0.9722, device='cuda:0')
# ensemble nr 10
# cost tensor(0.9709, device='cuda:0')
# ensemble nr 11
# cost tensor(0.9692, device='cuda:0')
# ensemble nr 12
# cost tensor(0.9675, device='cuda:0')
# ensemble nr 13
# cost tensor(0.9667, device='cuda:0')
# ensemble nr 14
# ...

# %%
EP_model_thresh.knn()
# Out:
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/
# (2800, 2800)
#                                                        Experiment  accuracy
# 0  natimg2800_M170717_MP034_2017-09-11.mat_V_ep_pytorch_tfidf.npy  0.383214
#        accuracy
# count  1.000000
# mean   0.383214
# std         NaN
# min    0.383214
# 25%    0.383214
# 50%    0.383214
# 75%    0.383214
# max    0.383214
#                                                        Experiment  accuracy
# 0  natimg2800_M170717_MP034_2017-09-11.mat_V_ep_pytorch_tfidf.npy  0.383214
