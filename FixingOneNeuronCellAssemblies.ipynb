# %%
import torch
import numpy as np
import scipy.io as sio
import os
import time
from scipy import stats

# %%
class EnsemblePursuitPyTorch():
    
    def calculate_cost_delta(self):
        cost_delta=torch.clamp(torch.matmul(self.current_v,self.X),min=0,max=None)**2/torch.matmul(self.current_v,self.current_v)-self.lambd
        return cost_delta
    
    def fit_one_assembly(self):
        '''
        Function for fitting one cell assembly and computing u and v of the currrent assembly (self.current_u,
        self.current_v).
        One neuron cell assemblies are excluded. 
        '''
        with torch.cuda.device(0) as device:
            #Fake i for initiating while loop. self.i stores the number of neurons in assemblies.
            self.i=1
            #If i is 1, e.g. only one neuron in fit cell assembly, will run fitting the assembly again. 
            #safety it to avoid infinite loops.
            safety_it=0
            n_of_neurons=100
            while self.i==1:
                top_neurons,_=self.corr_top_k(n_neurons=n_of_neurons)
                top_corr_neuron=self.select_top_k_corr_neuron(top_neurons,_,n_of_neurons)
                print('neuron',top_corr_neuron)
                #choose_neuron_idx=np.random.randint(0,self.sz[1],1)[0]
                choose_neuron_idx=top_corr_neuron
                #Array of keeping track of neurons in the cell assembly
                self.selected_neurons=torch.zeros([self.sz[1]]).cuda()
                self.selected_neurons[choose_neuron_idx]=1
                #Seed current_v
                self.current_v=self.X[:,choose_neuron_idx]
                #Fake cost to initiate while loop
                max_delta_cost=1000
                #reset i
                self.i=1
                while max_delta_cost>0:
                    cost_delta=self.calculate_cost_delta()
                    #invert the 0's and 1's in the array which stores which neurons have already 
                    #been selected into the assembly to use it as a mask
                    mask=self.selected_neurons.clone()
                    mask[self.selected_neurons==0]=1
                    mask[self.selected_neurons!=0]=0
                    masked_cost_delta=mask*cost_delta
                    values,sorted_neurons=masked_cost_delta.sort()
                    max_delta_neuron=sorted_neurons[-1]
                    max_delta_cost=values[-1]
                    if max_delta_cost>0:
                        self.current_v=(self.current_v+self.X[:,max_delta_neuron.item()])/2
                        self.selected_neurons[max_delta_neuron.item()]=1
                    self.i+=1
                safety_it+=1
                #Increase number of neurons to sample from if while loop hasn't been finding any assemblies.
                if safety_it>100:
                    n_of_neurons=500
                if safety_it>600:
                    n_of_neurons=1000
                if safety_it>1600:
                    raise ValueError('Assembly capacity too big, can\'t fit model')
            #Add final seed neuron to seed_neurons.        
            self.seed_neurons.append(top_corr_neuron)          
            #Calculate u based on final v fit for a cell assembly. 
            self.current_u=torch.clamp(torch.matmul(self.current_v,self.X),min=0,max=None)/torch.matmul(self.current_v,self.current_v)
            self.U=torch.cat((self.U,self.current_u.view(self.X.size(1),1)),1)
            self.V=torch.cat((self.V,self.current_v.view(1,self.X.size(0))),0)
    
    def corrcoef(self,x):
        '''
        Torch implementation of the full correlation matrix.
        '''
        # calculate covariance matrix of columns
        mean_x = torch.mean(x,0)
        xm = torch.sub(x,mean_x)
        c = x.mm(x.t())
        c = c / (x.size(1) - 1)

        # normalize covariance matrix
        d = torch.diag(c)
        stddev = torch.pow(d, 0.5)
        c = c.div(stddev.expand_as(c))
        c = c.div(stddev.expand_as(c).t())

        # clamp between -1 and 1
        c = torch.clamp(c, -1.0, 1.0)

        return c
    
    def corr_top_k(self,n_neurons=100):
        '''
        Finds n_neurons neurons that are on average most correlated to their 
        5 closest neighbors.
        '''
        #Compute full correlation matrix (works with one neuron per column,
        #so have to transpose.)
        corr=self.corrcoef(self.X.t())
        #Sorts each row of correlation matrix
        vals,ix=corr.sort(dim=1)
        #Discards the last entry corresponding to the diagonal 1 and then
        #selects 5 of the largest entries from sorted array.
        top_vals=vals[:,:-1][:,self.sz[1]-6:]
        #Averages the 5 top correlations.
        av=torch.mean(top_vals,dim=1)
        #Sorts the averages
        vals,top_neurons=torch.sort(av)
        #Selects top neurons
        top_neuron=top_neurons[self.sz[1]-(n_neurons+1):]
        top_val=vals[self.sz[1]-(n_neurons+1):]
        return top_neuron,top_val
          
    
    def select_top_k_corr_neuron(self,top_neuron,top_val,n_neurons=100):
        '''
        Randomly samples from k top correlated urons.
        '''
        #Randomly samples a neuron from the n_of_neurons top correlated.
        idx=torch.randint(0,n_neurons,size=(1,))
        print('top n', top_neuron[idx[0]].item(), top_val[idx[0]].item())
        return top_neuron[idx[0]].item()
    
    
    def fit_transform(self,X,lambd,n_ensembles=None):
        torch.manual_seed(7)
        with torch.cuda.device(0) as device:
            self.lambd=lambd
            #z-score data.
            self.X=stats.zscore(X+0.0000001,axis=0)
            #Creates cuda tensor from data
            self.X=torch.cuda.FloatTensor(self.X) 
            #Store dimensionalit of X for later use.
            self.sz=self.X.size()
            #Initializes U and V with zeros, later these will be discarded.
            self.U=torch.zeros((self.X.size(1),1)).cuda()
            self.V=torch.zeros([1,self.X.size(0)]).cuda()
            #List for storing the number of neurons in each fit assembly.
            self.nr_of_neurons=[]
            #List for storing the seed neurons for each assembly.
            self.seed_neurons=[]
            cost_lst=[]
            for iteration in range(0,n_ensembles):
                self.fit_one_assembly()
                self.nr_of_neurons.append(self.i)
                U_V=torch.mm(self.current_u.view(self.sz[1],1),self.current_v.view(1,self.sz[0]))
                U_V[U_V != U_V] = 0
                res=(self.X-U_V.t())
                self.X=res
                print('ensemble nr', iteration)
                #print('u',self.current_u)
                #print('v',self.current_v)
                #print('length v', torch.matmul(self.current_v,self.current_v))
                #print('norm',torch.norm(self.X))
                self.cost=torch.mean(torch.mul(res,res))
                print('cost',self.cost)
                cost_lst.append(self.cost.item())
            #After fitting arrays discard the zero initialization rows and columns from U and V.
            self.U=self.U[:,1:]
            self.V=self.V[1:,:]
            print(self.X.size())
            print(self.U.size())
            print(self.V.size())
            return torch.matmul(self.U,self.V).t().cpu(), self.nr_of_neurons, self.U.cpu(), self.V.cpu(), cost_lst, self.seed_neurons

# %%
X=sio.loadmat('/home/maria/Documents/EnsemblePursuit/data/natimg2800_M170717_MP034_2017-09-11.mat')['stim']['resp'][0][0]
X[X<0]=0
print(X.shape)
for col in range(0,X.shape[1]):
    if np.sum(X[:,col]==0)==X.shape[0]:
        print(col)
# Out:
# (5880, 10103)
# 8574

# %%
np.random.seed(7)
ep=EnsemblePursuitPyTorch()
s=time.time()
U_V,nr_of_neurons,U,V, cost_lst,seed_neurons=ep.fit_transform(X,500,1000)
e=time.time()
print(e-s)
print(nr_of_neurons)
print(cost_lst)
# Out:
# top n 1672 0.41533946990966797
# neuron 1672
# ensemble nr 0
# cost tensor(0.9983, device='cuda:0')
# top n 5168 0.48429423570632935
# neuron 5168
# ensemble nr 1
# cost tensor(0.9964, device='cuda:0')
# top n 196 0.4173440933227539
# neuron 196
# ensemble nr 2
# cost tensor(0.9941, device='cuda:0')
# top n 2233 0.4697026312351227
# neuron 2233
# ensemble nr 3
# cost tensor(0.9927, device='cuda:0')
# top n 1489 0.45894595980644226
# neuron 1489
# ensemble nr 4
# cost tensor(0.9911, device='cuda:0')
# top n 9367 0.432136207818985
# neuron 9367
# ensemble nr 5
# cost tensor(0.9895, device='cuda:0')
# top n 4115 0.47026801109313965
# neuron 4115
# ensemble nr 6
# cost tensor(0.9878, device='cuda:0')
# top n 2295 0.4510462284088135
# neuron 2295
# ensemble nr 7
# cost tensor(0.9860, device='cuda:0')
# top n 1408 0.4705081880092621
# neuron 1408
# ensemble nr 8
# cost tensor(0.9850, device='cuda:0')
# top n 223 0.43413883447647095
# neuron 223
# ensemble nr 9
# cost tensor(0.9830, device='cuda:0')
# top n 105 0.4322568476200104
# neuron 105
# ensemble nr 10
# cost tensor(0.9818, device='cuda:0')
# top n 9777 0.40935859084129333
# neuron 9777
# ensemble nr 11
# cost tensor(0.9803, device='cuda:0')
# top n 719 0.3950398564338684
# neuron 719
# ensemble nr 12
# cost tensor(0.9790, device='cuda:0')
# top n 3175 0.3967970907688141
# neuron 3175
# ensemble nr 13
# cost tensor(0.9780, device='cuda:0')
# top n 3214 0.4279780983924866
# neuron 3214
# ensemble nr 14
# cost tensor(0.9761, device='cuda:0')
# top n 2657 0.4015564024448395
# neuron 2657
# ensemble nr 15
# cost tensor(0.9753, device='cuda:0')
# top n 105 0.4275744557380676
# neuron 105
# ensemble nr 16
# cost tensor(0.9743, device='cuda:0')
# top n 1408 0.43233615159988403
# neuron 1408
# ensemble nr 17
# cost tensor(0.9733, device='cuda:0')
# top n 2342 0.4402131140232086
# neuron 2342
# ensemble nr 18
# cost tensor(0.9719, device='cuda:0')
# top n 5374 0.39308103919029236
# neuron 5374
# ensemble nr 19
# cost tensor(0.9710, device='cuda:0')
# top n 36 0.4604569971561432
# neuron 36
# ensemble nr 20
# cost tensor(0.9700, device='cuda:0')
# top n 9777 0.40700480341911316
# neuron 9777
# ensemble nr 21
# cost tensor(0.9686, device='cuda:0')
# top n 3183 0.45702409744262695
# neuron 3183
# ensemble nr 22
# cost tensor(0.9676, device='cuda:0')
# top n 6025 0.41340503096580505
# neuron 6025
# ensemble nr 23
# cost tensor(0.9658, device='cuda:0')
# top n 2144 0.384583443403244
# neuron 2144
# ensemble nr 24
# cost tensor(0.9648, device='cuda:0')
# top n 3214 0.4222652018070221
# neuron 3214
# ensemble nr 25
# cost tensor(0.9628, device='cuda:0')
# top n 2780 0.403564989566803
# neuron 2780
# ensemble nr 26
# cost tensor(0.9613, device='cuda:0')
# top n 1455 0.39106234908103943
# neuron 1455
# ensemble nr 27
# cost tensor(0.9603, device='cuda:0')
# top n 3179 0.39000704884529114
# neuron 3179
# ensemble nr 28
# cost tensor(0.9590, device='cuda:0')
# top n 9391 0.4302193820476532
# neuron 9391
# ensemble nr 29
# cost tensor(0.9578, device='cuda:0')
# top n 89 0.40211984515190125
# neuron 89
# ensemble nr 30
# cost tensor(0.9568, device='cuda:0')
# top n 1366 0.3905218541622162
# neuron 1366
# ensemble nr 31
# cost tensor(0.9556, device='cuda:0')
# top n 3442 0.3749498724937439
# neuron 3442
# ensemble nr 32
# cost tensor(0.9548, device='cuda:0')
# top n 7709 0.40922051668167114
# neuron 7709
# ensemble nr 33
# cost tensor(0.9537, device='cuda:0')
# top n 1413 0.36812207102775574
# neuron 1413
# ensemble nr 34
# cost tensor(0.9526, device='cuda:0')
# top n 2601 0.4204481244087219
# neuron 2601
# ensemble nr 35
# cost tensor(0.9516, device='cuda:0')
# top n 2479 0.3704851269721985
# neuron 2479
# ensemble nr 36
# cost tensor(0.9505, device='cuda:0')
# top n 8946 0.3734547793865204
# neuron 8946
# ensemble nr 37
# cost tensor(0.9496, device='cuda:0')
# top n 3033 0.3989895284175873
# neuron 3033
# ensemble nr 38
# cost tensor(0.9485, device='cuda:0')
# top n 7766 0.39190873503685
# neuron 7766
# ensemble nr 39
# cost tensor(0.9470, device='cuda:0')
# top n 3244 0.4089020788669586
# neuron 3244
# ensemble nr 40
# cost tensor(0.9463, device='cuda:0')
# top n 2470 0.39007630944252014
# neuron 2470
# ensemble nr 41
# cost tensor(0.9454, device='cuda:0')
# top n 6414 0.3597216308116913
# neuron 6414
# ensemble nr 42
# cost tensor(0.9447, device='cuda:0')
# top n 24 0.3586173951625824
# neuron 24
# ensemble nr 43
# cost tensor(0.9432, device='cuda:0')
# top n 149 0.37644320726394653
# neuron 149
# ensemble nr 44
# cost tensor(0.9419, device='cuda:0')
# top n 4403 0.3617754578590393
# neuron 4403
# ensemble nr 45
# cost tensor(0.9412, device='cuda:0')
# top n 1455 0.37658119201660156
# neuron 1455
# ensemble nr 46
# cost tensor(0.9399, device='cuda:0')
# top n 5168 0.42943960428237915
# neuron 5168
# ensemble nr 47
# cost tensor(0.9388, device='cuda:0')
# top n 8665 0.35328999161720276
# neuron 8665
# ensemble nr 48
# cost tensor(0.9381, device='cuda:0')
# top n 4415 0.3636295199394226
# neuron 4415
# ensemble nr 49
# cost tensor(0.9374, device='cuda:0')
# top n 7234 0.35111895203590393
# neuron 7234
# ensemble nr 50
# cost tensor(0.9364, device='cuda:0')
# top n 6354 0.35461536049842834
# neuron 6354
# ensemble nr 51
# cost tensor(0.9356, device='cuda:0')
# top n 2342 0.3494439125061035
# neuron 2342
# ensemble nr 52
# cost tensor(0.9345, device='cuda:0')
# top n 5168 0.39772507548332214
# neuron 5168
# ensemble nr 53
# cost tensor(0.9338, device='cuda:0')
# top n 4185 0.3454010784626007
# neuron 4185
# ensemble nr 54
# cost tensor(0.9331, device='cuda:0')
# top n 56 0.3793657720088959
# neuron 56
# ensemble nr 55
# cost tensor(0.9326, device='cuda:0')
# top n 1290 0.34395089745521545
# neuron 1290
# ensemble nr 56
# cost tensor(0.9321, device='cuda:0')
# top n 3065 0.375444233417511
# neuron 3065
# ensemble nr 57
# cost tensor(0.9313, device='cuda:0')
# top n 9147 0.3550686538219452
# neuron 9147
# ensemble nr 58
# cost tensor(0.9301, device='cuda:0')
# top n 3244 0.3530644178390503
# neuron 3244
# ensemble nr 59
# cost tensor(0.9294, device='cuda:0')
# top n 7437 0.362483412027359
# neuron 7437
# ensemble nr 60
# cost tensor(0.9285, device='cuda:0')
# top n 1483 0.3498326241970062
# neuron 1483
# ensemble nr 61
# cost tensor(0.9275, device='cuda:0')
# top n 9632 0.36359113454818726
# neuron 9632
# ensemble nr 62
# cost tensor(0.9265, device='cuda:0')
# top n 3057 0.3510352075099945
# neuron 3057
# ensemble nr 63
# cost tensor(0.9259, device='cuda:0')
# top n 3954 0.3659159243106842
# neuron 3954
# ensemble nr 64
# cost tensor(0.9253, device='cuda:0')
# top n 7437 0.3556487262248993
# neuron 7437
# ensemble nr 65
# cost tensor(0.9245, device='cuda:0')
# top n 6414 0.3561649024486542
# neuron 6414
# ensemble nr 66
# cost tensor(0.9235, device='cuda:0')
# top n 2703 0.3510781228542328
# neuron 2703
# ensemble nr 67
# cost tensor(0.9229, device='cuda:0')
# top n 2295 0.35203105211257935
# neuron 2295
# ensemble nr 68
# cost tensor(0.9222, device='cuda:0')
# top n 299 0.3351265490055084
# neuron 299
# ensemble nr 69
# cost tensor(0.9218, device='cuda:0')
# top n 3606 0.37399551272392273
# neuron 3606
# ensemble nr 70
# cost tensor(0.9211, device='cuda:0')
# top n 8217 0.4051191508769989
# neuron 8217
# ensemble nr 71
# cost tensor(0.9204, device='cuda:0')
# top n 6450 0.33079537749290466
# neuron 6450
# ensemble nr 72
# cost tensor(0.9198, device='cuda:0')
# top n 4015 0.34096288681030273
# neuron 4015
# ensemble nr 73
# cost tensor(0.9189, device='cuda:0')
# top n 1408 0.39208313822746277
# neuron 1408
# ensemble nr 74
# cost tensor(0.9185, device='cuda:0')
# top n 8217 0.39669331908226013
# neuron 8217
# ensemble nr 75
# cost tensor(0.9178, device='cuda:0')
# top n 984 0.40374088287353516
# neuron 984
# ensemble nr 76
# cost tensor(0.9173, device='cuda:0')
# top n 3810 0.3465683162212372
# neuron 3810
# ensemble nr 77
# cost tensor(0.9166, device='cuda:0')
# top n 6954 0.34316951036453247
# neuron 6954
# ensemble nr 78
# cost tensor(0.9158, device='cuda:0')
# top n 3938 0.33808812499046326
# neuron 3938
# ensemble nr 79
# cost tensor(0.9154, device='cuda:0')
# top n 3681 0.35920390486717224
# neuron 3681
# ensemble nr 80
# cost tensor(0.9150, device='cuda:0')
# top n 7430 0.34471532702445984
# neuron 7430
# ensemble nr 81
# cost tensor(0.9143, device='cuda:0')
# top n 2953 0.3304658830165863
# neuron 2953
# ensemble nr 82
# cost tensor(0.9136, device='cuda:0')
# top n 231 0.3376629948616028
# neuron 231
# ensemble nr 83
# cost tensor(0.9127, device='cuda:0')
# top n 2295 0.32277026772499084
# neuron 2295
# ensemble nr 84
# cost tensor(0.9123, device='cuda:0')
# top n 6169 0.3509329557418823
# neuron 6169
# ensemble nr 85
# cost tensor(0.9115, device='cuda:0')
# top n 574 0.36231499910354614
# neuron 574
# ensemble nr 86
# cost tensor(0.9109, device='cuda:0')
# top n 4314 0.33099231123924255
# neuron 4314
# ensemble nr 87
# cost tensor(0.9103, device='cuda:0')
# top n 6918 0.32041797041893005
# neuron 6918
# ensemble nr 88
# cost tensor(0.9098, device='cuda:0')
# top n 5262 0.32127898931503296
# neuron 5262
# ensemble nr 89
# cost tensor(0.9090, device='cuda:0')
# top n 6806 0.3410807251930237
# neuron 6806
# ensemble nr 90
# cost tensor(0.9083, device='cuda:0')
# top n 689 0.31337255239486694
# neuron 689
# ensemble nr 91
# cost tensor(0.9079, device='cuda:0')
# top n 3505 0.3953709304332733
# neuron 3505
# ensemble nr 92
# cost tensor(0.9073, device='cuda:0')
# top n 6025 0.3288411796092987
# neuron 6025
# ensemble nr 93
# cost tensor(0.9067, device='cuda:0')
# top n 6686 0.3506530821323395
# neuron 6686
# ensemble nr 94
# cost tensor(0.9060, device='cuda:0')
# top n 2205 0.3807002007961273
# neuron 2205
# ensemble nr 95
# cost tensor(0.9054, device='cuda:0')
# top n 3500 0.3139466643333435
# neuron 3500
# ensemble nr 96
# cost tensor(0.9049, device='cuda:0')
# top n 6545 0.339323490858078
# neuron 6545
# ensemble nr 97
# cost tensor(0.9040, device='cuda:0')
# top n 2628 0.32167965173721313
# neuron 2628
# ensemble nr 98
# cost tensor(0.9037, device='cuda:0')
# top n 4133 0.313965767621994
# neuron 4133
# ensemble nr 99
# cost tensor(0.9029, device='cuda:0')
# top n 7766 0.36251673102378845
# neuron 7766
# ensemble nr 100
# cost tensor(0.9023, device='cuda:0')
# top n 6806 0.32854780554771423
# neuron 6806
# ensemble nr 101
# cost tensor(0.9016, device='cuda:0')
# top n 4821 0.31795448064804077
# neuron 4821
# ensemble nr 102
# cost tensor(0.9012, device='cuda:0')
# top n 307 0.3316381275653839
# neuron 307
# ensemble nr 103
# cost tensor(0.9005, device='cuda:0')
# top n 4484 0.35106346011161804
# neuron 4484
# ensemble nr 104
# cost tensor(0.9000, device='cuda:0')
# top n 8786 0.3068956732749939
# neuron 8786
# ensemble nr 105
# cost tensor(0.8994, device='cuda:0')
# top n 97 0.30866050720214844
# neuron 97
# ensemble nr 106
# cost tensor(0.8989, device='cuda:0')
# top n 3380 0.32060912251472473
# neuron 3380
# ensemble nr 107
# cost tensor(0.8982, device='cuda:0')
# top n 2030 0.3072279989719391
# neuron 2030
# ensemble nr 108
# cost tensor(0.8977, device='cuda:0')
# top n 4680 0.3064288794994354
# neuron 4680
# ensemble nr 109
# cost tensor(0.8970, device='cuda:0')
# top n 2309 0.3011420667171478
# neuron 2309
# ensemble nr 110
# cost tensor(0.8964, device='cuda:0')
# top n 8788 0.3300265967845917
# neuron 8788
# ensemble nr 111
# cost tensor(0.8955, device='cuda:0')
# top n 169 0.3246358633041382
# neuron 169
# ensemble nr 112
# cost tensor(0.8949, device='cuda:0')
# top n 7430 0.31368884444236755
# neuron 7430
# ensemble nr 113
# cost tensor(0.8944, device='cuda:0')
# top n 9302 0.3002098798751831
# neuron 9302
# ensemble nr 114
# cost tensor(0.8936, device='cuda:0')
# top n 2716 0.31348249316215515
# neuron 2716
# ensemble nr 115
# cost tensor(0.8933, device='cuda:0')
# top n 2331 0.3262798488140106
# neuron 2331
# ensemble nr 116
# cost tensor(0.8926, device='cuda:0')
# top n 5444 0.30151110887527466
# neuron 5444
# ensemble nr 117
# cost tensor(0.8921, device='cuda:0')
# top n 9328 0.29996371269226074
# neuron 9328
# ensemble nr 118
# cost tensor(0.8914, device='cuda:0')
# top n 735 0.30064278841018677
# neuron 735
# ensemble nr 119
# cost tensor(0.8911, device='cuda:0')
# top n 4434 0.2983231246471405
# neuron 4434
# ensemble nr 120
# cost tensor(0.8906, device='cuda:0')
# top n 2329 0.332820326089859
# neuron 2329
# ensemble nr 121
# cost tensor(0.8899, device='cuda:0')
# top n 1468 0.31061872839927673
# neuron 1468
# ensemble nr 122
# cost tensor(0.8890, device='cuda:0')
# top n 1850 0.2951844036579132
# neuron 1850
# ensemble nr 123
# cost tensor(0.8886, device='cuda:0')
# top n 2601 0.37810179591178894
# neuron 2601
# ensemble nr 124
# cost tensor(0.8881, device='cuda:0')
# top n 3183 0.37194475531578064
# neuron 3183
# ensemble nr 125
# cost tensor(0.8875, device='cuda:0')
# top n 2642 0.3069533705711365
# neuron 2642
# ensemble nr 126
# cost tensor(0.8870, device='cuda:0')
# top n 149 0.29749369621276855
# neuron 149
# ensemble nr 127
# cost tensor(0.8864, device='cuda:0')
# top n 1481 0.3239162862300873
# neuron 1481
# ensemble nr 128
# cost tensor(0.8858, device='cuda:0')
# top n 9391 0.3141993284225464
# neuron 9391
# ensemble nr 129
# cost tensor(0.8852, device='cuda:0')
# top n 8028 0.2960941791534424
# neuron 8028
# ensemble nr 130
# cost tensor(0.8847, device='cuda:0')
# top n 5289 0.2893868386745453
# neuron 5289
# ensemble nr 131
# cost tensor(0.8841, device='cuda:0')
# top n 5667 0.28725770115852356
# neuron 5667
# ensemble nr 132
# cost tensor(0.8832, device='cuda:0')
# top n 6475 0.28978896141052246
# neuron 6475
# ensemble nr 133
# cost tensor(0.8827, device='cuda:0')
# top n 3340 0.28727927803993225
# neuron 3340
# ensemble nr 134
# cost tensor(0.8822, device='cuda:0')
# top n 8861 0.28669705986976624
# neuron 8861
# ensemble nr 135
# cost tensor(0.8816, device='cuda:0')
# top n 3452 0.2930601239204407
# neuron 3452
# ensemble nr 136
# cost tensor(0.8810, device='cuda:0')
# top n 8165 0.2953859567642212
# neuron 8165
# ensemble nr 137
# cost tensor(0.8804, device='cuda:0')
# top n 3674 0.2855066955089569
# neuron 3674
# ensemble nr 138
# cost tensor(0.8797, device='cuda:0')
# top n 1627 0.2879318296909332
# neuron 1627
# ensemble nr 139
# cost tensor(0.8791, device='cuda:0')
# top n 4680 0.2937414348125458
# neuron 4680
# ensemble nr 140
# cost tensor(0.8787, device='cuda:0')
# top n 8975 0.3169688582420349
# neuron 8975
# ensemble nr 141
# cost tensor(0.8780, device='cuda:0')
# top n 6599 0.28387734293937683
# neuron 6599
# ensemble nr 142
# cost tensor(0.8775, device='cuda:0')
# top n 8637 0.29438820481300354
# neuron 8637
# ensemble nr 143
# cost tensor(0.8769, device='cuda:0')
# top n 105 0.30658894777297974
# neuron 105
# ensemble nr 144
# cost tensor(0.8764, device='cuda:0')
# top n 4066 0.3148106336593628
# neuron 4066
# ensemble nr 145
# cost tensor(0.8760, device='cuda:0')
# top n 6174 0.30362939834594727
# neuron 6174
# ensemble nr 146
# cost tensor(0.8754, device='cuda:0')
# top n 1041 0.35070037841796875
# neuron 1041
# ensemble nr 147
# cost tensor(0.8748, device='cuda:0')
# top n 8190 0.28789928555488586
# neuron 8190
# ensemble nr 148
# cost tensor(0.8741, device='cuda:0')
# top n 2057 0.2944867014884949
# neuron 2057
# ensemble nr 149
# cost tensor(0.8736, device='cuda:0')
# top n 8041 0.292694628238678
# neuron 8041
# ensemble nr 150
# cost tensor(0.8731, device='cuda:0')
# top n 9414 0.3287460505962372
# neuron 9414
# ensemble nr 151
# cost tensor(0.8727, device='cuda:0')
# top n 3991 0.284019410610199
# neuron 3991
# ensemble nr 152
# cost tensor(0.8723, device='cuda:0')
# top n 123 0.2804134786128998
# neuron 123
# ensemble nr 153
# cost tensor(0.8718, device='cuda:0')
# top n 3536 0.28741103410720825
# neuron 3536
# ensemble nr 154
# cost tensor(0.8714, device='cuda:0')
# top n 5379 0.29927727580070496
# neuron 5379
# ensemble nr 155
# cost tensor(0.8710, device='cuda:0')
# top n 4978 0.30666568875312805
# neuron 4978
# ensemble nr 156
# cost tensor(0.8705, device='cuda:0')
# top n 4182 0.27554261684417725
# neuron 4182
# ensemble nr 157
# cost tensor(0.8701, device='cuda:0')
# top n 5424 0.2846740186214447
# neuron 5424
# ensemble nr 158
# cost tensor(0.8697, device='cuda:0')
# top n 9147 0.3217296600341797
# neuron 9147
# ensemble nr 159
# cost tensor(0.8691, device='cuda:0')
# top n 3230 0.30950090289115906
# neuron 3230
# ensemble nr 160
# cost tensor(0.8685, device='cuda:0')
# top n 1956 0.27292194962501526
# neuron 1956
# ensemble nr 161
# cost tensor(0.8681, device='cuda:0')
# top n 6208 0.2813245952129364
# neuron 6208
# ensemble nr 162
# cost tensor(0.8677, device='cuda:0')
# top n 1568 0.30250200629234314
# neuron 1568
# ensemble nr 163
# cost tensor(0.8674, device='cuda:0')
# top n 2460 0.29632803797721863
# neuron 2460
# ensemble nr 164
# cost tensor(0.8669, device='cuda:0')
# top n 9576 0.27318626642227173
# neuron 9576
# ensemble nr 165
# cost tensor(0.8665, device='cuda:0')
# top n 2474 0.29235026240348816
# neuron 2474
# ensemble nr 166
# cost tensor(0.8660, device='cuda:0')
# top n 819 0.28000298142433167
# neuron 819
# ensemble nr 167
# cost tensor(0.8656, device='cuda:0')
# top n 742 0.27286645770072937
# neuron 742
# ensemble nr 168
# cost tensor(0.8652, device='cuda:0')
# top n 1663 0.44675299525260925
# neuron 1663
# ensemble nr 169
# cost tensor(0.8647, device='cuda:0')
# top n 4645 0.43526312708854675
# neuron 4645
# ensemble nr 170
# cost tensor(0.8642, device='cuda:0')
# top n 99 0.6039267182350159
# neuron 99
# ensemble nr 171
# cost tensor(0.8638, device='cuda:0')
# top n 2277 0.599177896976471
# neuron 2277
# ensemble nr 172
# cost tensor(0.8634, device='cuda:0')
# top n 4863 0.6729742884635925
# neuron 4863
# ensemble nr 173
# cost tensor(0.8631, device='cuda:0')
# top n 1020 0.6195312142372131
# neuron 1020
# ensemble nr 174
# cost tensor(0.8627, device='cuda:0')
# top n 8723 0.6201118230819702
# neuron 8723
# ensemble nr 175
# cost tensor(0.8623, device='cuda:0')
# top n 4403 0.5965811014175415
# neuron 4403
# ensemble nr 176
# cost tensor(0.8619, device='cuda:0')
# top n 2854 0.6504265666007996
# neuron 2854
# ensemble nr 177
# cost tensor(0.8614, device='cuda:0')
# top n 702 0.5932124257087708
# neuron 702
# ensemble nr 178
# cost tensor(0.8610, device='cuda:0')
# top n 2746 0.5982522368431091
# neuron 2746
# ensemble nr 179
# cost tensor(0.8606, device='cuda:0')
# top n 3429 0.593113899230957
# neuron 3429
# ensemble nr 180
# cost tensor(0.8602, device='cuda:0')
# top n 3958 0.6005157232284546
# neuron 3958
# ensemble nr 181
# cost tensor(0.8598, device='cuda:0')
# top n 3511 0.6038844585418701
# neuron 3511
# ensemble nr 182
# cost tensor(0.8594, device='cuda:0')
# top n 2328 0.6222836971282959
# neuron 2328
# ensemble nr 183
# cost tensor(0.8590, device='cuda:0')
# top n 695 0.6069912314414978
# neuron 695
# ensemble nr 184
# cost tensor(0.8586, device='cuda:0')
# top n 4022 0.6110048294067383
# neuron 4022
# ensemble nr 185
# cost tensor(0.8583, device='cuda:0')
# top n 9459 0.5905290246009827
# neuron 9459
# ensemble nr 186
# cost tensor(0.8578, device='cuda:0')
# top n 2183 0.6008539199829102
# neuron 2183
# ensemble nr 187
# cost tensor(0.8574, device='cuda:0')
# top n 4483 0.595360517501831
# neuron 4483
# ensemble nr 188
# cost tensor(0.8570, device='cuda:0')
# top n 3433 0.5929362177848816
# neuron 3433
# ensemble nr 189
# cost tensor(0.8567, device='cuda:0')
# top n 1988 0.6192582249641418
# neuron 1988
# ensemble nr 190
# cost tensor(0.8562, device='cuda:0')
# top n 4028 0.5867711305618286
# neuron 4028
# ensemble nr 191
# cost tensor(0.8557, device='cuda:0')
# top n 1441 0.594436764717102
# neuron 1441
# ensemble nr 192
# cost tensor(0.8552, device='cuda:0')
# top n 3369 0.5876029133796692
# neuron 3369
# ensemble nr 193
# cost tensor(0.8548, device='cuda:0')
# top n 642 0.5864847302436829
# neuron 642
# ensemble nr 194
# cost tensor(0.8544, device='cuda:0')
# top n 742 1.0
# neuron 742
# ensemble nr 195
# cost tensor(0.8544, device='cuda:0')
# top n 6652 0.5846208930015564
# neuron 6652
# ensemble nr 196
# cost tensor(0.8541, device='cuda:0')
# top n 6022 0.5918710827827454
# neuron 6022
# ensemble nr 197
# cost tensor(0.8537, device='cuda:0')
# top n 6422 0.5888480544090271
# neuron 6422
# ensemble nr 198
# cost tensor(0.8533, device='cuda:0')
# top n 6169 0.5844669342041016
# neuron 6169
# ensemble nr 199
# cost tensor(0.8528, device='cuda:0')
# top n 2218 0.6023651361465454
# neuron 2218
# ensemble nr 200
# cost tensor(0.8525, device='cuda:0')
# top n 1890 0.5885602235794067
# neuron 1890
# ensemble nr 201
# cost tensor(0.8521, device='cuda:0')
# top n 1029 0.5969533324241638
# neuron 1029
# ensemble nr 202
# cost tensor(0.8518, device='cuda:0')
# top n 7914 0.5866395235061646
# neuron 7914
# ensemble nr 203
# cost tensor(0.8513, device='cuda:0')
# top n 2250 0.5861385464668274
# neuron 2250
# ensemble nr 204
# cost tensor(0.8508, device='cuda:0')
# top n 678 0.6144503355026245
# neuron 678
# ensemble nr 205
# cost tensor(0.8505, device='cuda:0')
# top n 2398 0.5939359664916992
# neuron 2398
# ensemble nr 206
# cost tensor(0.8502, device='cuda:0')
# top n 146 0.5898085832595825
# neuron 146
# ensemble nr 207
# cost tensor(0.8498, device='cuda:0')
# top n 516 0.605778694152832
# neuron 516
# ensemble nr 208
# cost tensor(0.8493, device='cuda:0')
# top n 3028 0.6015021204948425
# neuron 3028
# ensemble nr 209
# cost tensor(0.8489, device='cuda:0')
# top n 1578 0.5837600827217102
# neuron 1578
# ensemble nr 210
# cost tensor(0.8485, device='cuda:0')
# top n 3106 0.6045603156089783
# neuron 3106
# ensemble nr 211
# cost tensor(0.8481, device='cuda:0')
# top n 1734 0.5829923748970032
# neuron 1734
# ensemble nr 212
# cost tensor(0.8477, device='cuda:0')
# top n 9912 0.5884557962417603
# neuron 9912
# ensemble nr 213
# cost tensor(0.8472, device='cuda:0')
# top n 1455 0.6044997572898865
# neuron 1455
# ensemble nr 214
# cost tensor(0.8468, device='cuda:0')
# top n 1967 0.5829110145568848
# neuron 1967
# ensemble nr 215
# cost tensor(0.8464, device='cuda:0')
# top n 3519 0.586584746837616
# neuron 3519
# ensemble nr 216
# cost tensor(0.8458, device='cuda:0')
# top n 2504 0.6072430610656738
# neuron 2504
# ensemble nr 217
# cost tensor(0.8455, device='cuda:0')
# top n 6469 0.5874301791191101
# neuron 6469
# ensemble nr 218
# cost tensor(0.8449, device='cuda:0')
# top n 145 0.5907883644104004
# neuron 145
# ensemble nr 219
# cost tensor(0.8445, device='cuda:0')
# top n 5215 0.5777944326400757
# neuron 5215
# ensemble nr 220
# cost tensor(0.8441, device='cuda:0')
# top n 508 0.7708143591880798
# neuron 508
# ensemble nr 221
# cost tensor(0.8438, device='cuda:0')
# top n 3785 0.7520772814750671
# neuron 3785
# ensemble nr 222
# cost tensor(0.8434, device='cuda:0')
# top n 2444 0.7413680553436279
# neuron 2444
# ensemble nr 223
# cost tensor(0.8430, device='cuda:0')
# top n 830 0.7465746402740479
# neuron 830
# ensemble nr 224
# cost tensor(0.8426, device='cuda:0')
# top n 3726 0.7617416977882385
# neuron 3726
# ensemble nr 225
# cost tensor(0.8421, device='cuda:0')
# top n 611 0.7413265705108643
# neuron 611
# ensemble nr 226
# cost tensor(0.8418, device='cuda:0')
# top n 532 0.7426570057868958
# neuron 532
# ensemble nr 227
# cost tensor(0.8415, device='cuda:0')
# top n 221 0.7894372940063477
# neuron 221
# ensemble nr 228
# cost tensor(0.8410, device='cuda:0')
# top n 2093 0.7528702616691589
# neuron 2093
# ensemble nr 229
# cost tensor(0.8407, device='cuda:0')
# top n 964 0.7405903935432434
# neuron 964
# ensemble nr 230
# cost tensor(0.8403, device='cuda:0')
# top n 2806 0.7448817491531372
# neuron 2806
# ensemble nr 231
# cost tensor(0.8399, device='cuda:0')
# top n 2148 0.7406899333000183
# neuron 2148
# ensemble nr 232
# cost tensor(0.8395, device='cuda:0')
# top n 9161 0.7438641786575317
# neuron 9161
# ensemble nr 233
# cost tensor(0.8391, device='cuda:0')
# top n 1286 0.7876874208450317
# neuron 1286
# ensemble nr 234
# cost tensor(0.8387, device='cuda:0')
# top n 5978 0.7416227459907532
# neuron 5978
# ensemble nr 235
# cost tensor(0.8383, device='cuda:0')
# top n 9970 0.7520419955253601
# neuron 9970
# ensemble nr 236
# cost tensor(0.8379, device='cuda:0')
# top n 1452 0.7560116648674011
# neuron 1452
# ensemble nr 237
# cost tensor(0.8375, device='cuda:0')
# top n 3538 0.7394489645957947
# neuron 3538
# ensemble nr 238
# cost tensor(0.8371, device='cuda:0')
# top n 2918 0.7452883720397949
# neuron 2918
# ensemble nr 239
# cost tensor(0.8366, device='cuda:0')
# top n 2031 0.7367410063743591
# neuron 2031
# ensemble nr 240
# cost tensor(0.8362, device='cuda:0')
# top n 3447 0.7373788952827454
# neuron 3447
# ensemble nr 241
# cost tensor(0.8358, device='cuda:0')
# top n 1120 0.7388939261436462
# neuron 1120
# ensemble nr 242
# cost tensor(0.8353, device='cuda:0')
# top n 6248 0.763252317905426
# neuron 6248
# ensemble nr 243
# cost tensor(0.8349, device='cuda:0')
# top n 2197 0.7483536005020142
# neuron 2197
# ensemble nr 244
# cost tensor(0.8344, device='cuda:0')
# top n 3693 0.7382925152778625
# neuron 3693
# ensemble nr 245
# cost tensor(0.8340, device='cuda:0')
# top n 8474 0.7355391383171082
# neuron 8474
# ensemble nr 246
# cost tensor(0.8336, device='cuda:0')
# top n 5397 0.7470657229423523
# neuron 5397
# ensemble nr 247
# cost tensor(0.8331, device='cuda:0')
# top n 2534 0.7552666068077087
# neuron 2534
# ensemble nr 248
# cost tensor(0.8327, device='cuda:0')
# top n 5365 0.738905131816864
# neuron 5365
# ensemble nr 249
# cost tensor(0.8323, device='cuda:0')
# top n 8878 0.7358714938163757
# neuron 8878
# ensemble nr 250
# cost tensor(0.8319, device='cuda:0')
# top n 6796 0.7437444925308228
# neuron 6796
# ensemble nr 251
# cost tensor(0.8316, device='cuda:0')
# top n 8593 0.7346919178962708
# neuron 8593
# ensemble nr 252
# cost tensor(0.8310, device='cuda:0')
# top n 793 0.7509218454360962
# neuron 793
# ensemble nr 253
# cost tensor(0.8306, device='cuda:0')
# top n 4149 0.7344912886619568
# neuron 4149
# ensemble nr 254
# cost tensor(0.8302, device='cuda:0')
# top n 242 0.7697320580482483
# neuron 242
# ensemble nr 255
# cost tensor(0.8298, device='cuda:0')
# top n 273 0.73763507604599
# neuron 273
# ensemble nr 256
# cost tensor(0.8295, device='cuda:0')
# top n 1976 0.7513875365257263
# neuron 1976
# ensemble nr 257
# cost tensor(0.8292, device='cuda:0')
# top n 321 0.778351902961731
# neuron 321
# ensemble nr 258
# cost tensor(0.8289, device='cuda:0')
# top n 625 0.7340131998062134
# neuron 625
# ensemble nr 259
# cost tensor(0.8285, device='cuda:0')
# top n 137 0.7397916316986084
# neuron 137
# ensemble nr 260
# cost tensor(0.8283, device='cuda:0')
# top n 1153 0.7334015965461731
# neuron 1153
# ensemble nr 261
# cost tensor(0.8279, device='cuda:0')
# top n 1466 0.7325335144996643
# neuron 1466
# ensemble nr 262
# cost tensor(0.8276, device='cuda:0')
# top n 1842 0.7328417301177979
# neuron 1842
# ensemble nr 263
# cost tensor(0.8274, device='cuda:0')
# top n 9064 0.7407363653182983
# neuron 9064
# ensemble nr 264
# cost tensor(0.8270, device='cuda:0')
# top n 3597 0.7379263639450073
# neuron 3597
# ensemble nr 265
# cost tensor(0.8267, device='cuda:0')
# top n 1403 0.7943517565727234
# neuron 1403
# ensemble nr 266
# cost tensor(0.8264, device='cuda:0')
# top n 1761 0.7353013157844543
# neuron 1761
# ensemble nr 267
# cost tensor(0.8260, device='cuda:0')
# top n 3971 0.8350479006767273
# neuron 3971
# ensemble nr 268
# cost tensor(0.8257, device='cuda:0')
# top n 561 0.733891487121582
# neuron 561
# ensemble nr 269
# cost tensor(0.8254, device='cuda:0')
# top n 1355 0.7338634729385376
# neuron 1355
# ensemble nr 270
# cost tensor(0.8251, device='cuda:0')
# top n 8386 0.7317537665367126
# neuron 8386
# ensemble nr 271
# cost tensor(0.8247, device='cuda:0')
# top n 574 0.7586433291435242
# neuron 574
# ensemble nr 272
# cost tensor(0.8243, device='cuda:0')
# top n 8 0.7321130633354187
# neuron 8
# ensemble nr 273
# cost tensor(0.8240, device='cuda:0')
# top n 7552 0.7381787300109863
# neuron 7552
# ensemble nr 274
# cost tensor(0.8236, device='cuda:0')
# top n 5643 0.730336606502533
# neuron 5643
# ensemble nr 275
# cost tensor(0.8233, device='cuda:0')
# top n 1716 0.7421642541885376
# neuron 1716
# ensemble nr 276
# cost tensor(0.8230, device='cuda:0')
# top n 5267 0.7290959358215332
# neuron 5267
# ensemble nr 277
# cost tensor(0.8226, device='cuda:0')
# top n 190 0.7449223399162292
# neuron 190
# ensemble nr 278
# cost tensor(0.8222, device='cuda:0')
# top n 8606 0.7336992621421814
# neuron 8606
# ensemble nr 279
# cost tensor(0.8218, device='cuda:0')
# top n 2710 0.7565774917602539
# neuron 2710
# ensemble nr 280
# cost tensor(0.8214, device='cuda:0')
# top n 1480 0.7662020325660706
# neuron 1480
# ensemble nr 281
# cost tensor(0.8211, device='cuda:0')
# top n 4391 0.7380944490432739
# neuron 4391
# ensemble nr 282
# cost tensor(0.8208, device='cuda:0')
# top n 6662 0.7435707449913025
# neuron 6662
# ensemble nr 283
# cost tensor(0.8204, device='cuda:0')
# top n 971 0.7327839136123657
# neuron 971
# ensemble nr 284
# cost tensor(0.8200, device='cuda:0')
# top n 8316 0.7409612536430359
# neuron 8316
# ensemble nr 285
# cost tensor(0.8196, device='cuda:0')
# top n 6456 0.731692910194397
# neuron 6456
# ensemble nr 286
# cost tensor(0.8192, device='cuda:0')
# top n 2903 0.7407099008560181
# neuron 2903
# ensemble nr 287
# cost tensor(0.8189, device='cuda:0')
# top n 3698 0.7367245554924011
# neuron 3698
# ensemble nr 288
# cost tensor(0.8186, device='cuda:0')
# top n 188 0.7364888191223145
# neuron 188
# ensemble nr 289
# cost tensor(0.8183, device='cuda:0')
# top n 9305 0.7278797030448914
# neuron 9305
# ensemble nr 290
# cost tensor(0.8179, device='cuda:0')
# top n 90 0.7335931062698364
# neuron 90
# ensemble nr 291
# cost tensor(0.8176, device='cuda:0')
# top n 9661 0.7276560664176941
# neuron 9661
# ensemble nr 292
# cost tensor(0.8173, device='cuda:0')
# top n 8384 0.7300721406936646
# neuron 8384
# ensemble nr 293
# cost tensor(0.8169, device='cuda:0')
# top n 7418 0.734646737575531
# neuron 7418
# ensemble nr 294
# cost tensor(0.8166, device='cuda:0')
# top n 3240 0.731601893901825
# neuron 3240
# ensemble nr 295
# cost tensor(0.8163, device='cuda:0')
# top n 6009 0.729426383972168
# neuron 6009
# ensemble nr 296
# cost tensor(0.8159, device='cuda:0')
# top n 1543 0.731817364692688
# neuron 1543
# ensemble nr 297
# cost tensor(0.8154, device='cuda:0')
# top n 789 0.7348644137382507
# neuron 789
# ensemble nr 298
# cost tensor(0.8150, device='cuda:0')
# top n 7642 0.7269335389137268
# neuron 7642
# ensemble nr 299
# cost tensor(0.8145, device='cuda:0')
# top n 1407 0.7323196530342102
# neuron 1407
# ensemble nr 300
# cost tensor(0.8141, device='cuda:0')
# top n 9118 0.7570413947105408
# neuron 9118
# ensemble nr 301
# cost tensor(0.8137, device='cuda:0')
# top n 104 0.7287507057189941
# neuron 104
# ensemble nr 302
# cost tensor(0.8134, device='cuda:0')
# top n 3026 0.7342115640640259
# neuron 3026
# ensemble nr 303
# cost tensor(0.8131, device='cuda:0')
# top n 6742 0.7284793257713318
# neuron 6742
# ensemble nr 304
# cost tensor(0.8128, device='cuda:0')
# top n 403 0.7261800169944763
# neuron 403
# ensemble nr 305
# cost tensor(0.8125, device='cuda:0')
# top n 5338 0.7444650530815125
# neuron 5338
# ensemble nr 306
# cost tensor(0.8121, device='cuda:0')
# top n 4645 1.0
# neuron 4645
# ensemble nr 307
# cost tensor(0.8121, device='cuda:0')
# top n 2529 0.7273738384246826
# neuron 2529
# ensemble nr 308
# cost tensor(0.8117, device='cuda:0')
# top n 7814 0.7291468977928162
# neuron 7814
# ensemble nr 309
# cost tensor(0.8113, device='cuda:0')
# top n 666 0.7251065969467163
# neuron 666
# ensemble nr 310
# cost tensor(0.8110, device='cuda:0')
# top n 899 0.7281987071037292
# neuron 899
# ensemble nr 311
# cost tensor(0.8107, device='cuda:0')
# top n 8121 0.7278730273246765
# neuron 8121
# ensemble nr 312
# cost tensor(0.8103, device='cuda:0')
# top n 2158 0.7251448631286621
# neuron 2158
# ensemble nr 313
# cost tensor(0.8100, device='cuda:0')
# top n 9369 0.7271963953971863
# neuron 9369
# ensemble nr 314
# cost tensor(0.8096, device='cuda:0')
# top n 4780 0.7298301458358765
# neuron 4780
# ensemble nr 315
# cost tensor(0.8093, device='cuda:0')
# top n 934 0.7256657481193542
# neuron 934
# ensemble nr 316
# cost tensor(0.8090, device='cuda:0')
# top n 3111 0.7274379134178162
# neuron 3111
# ensemble nr 317
# cost tensor(0.8086, device='cuda:0')
# top n 7442 0.7248932123184204
# neuron 7442
# ensemble nr 318
# cost tensor(0.8081, device='cuda:0')
# top n 9574 0.9077789187431335
# neuron 9574
# ensemble nr 319
# cost tensor(0.8079, device='cuda:0')
# top n 1387 0.8987105488777161
# neuron 1387
# ensemble nr 320
# cost tensor(0.8076, device='cuda:0')
# top n 477 0.9023639559745789
# neuron 477
# ensemble nr 321
# cost tensor(0.8073, device='cuda:0')
# top n 365 0.8939141631126404
# neuron 365
# ensemble nr 322
# cost tensor(0.8070, device='cuda:0')
# top n 1660 0.8972568511962891
# neuron 1660
# ensemble nr 323
# cost tensor(0.8066, device='cuda:0')
# top n 901 0.8987183570861816
# neuron 901
# ensemble nr 324
# cost tensor(0.8063, device='cuda:0')
# top n 1860 0.8922050595283508
# neuron 1860
# ensemble nr 325
# cost tensor(0.8061, device='cuda:0')
# top n 9381 0.8973992466926575
# neuron 9381
# ensemble nr 326
# cost tensor(0.8057, device='cuda:0')
# top n 4405 0.8987812995910645
# neuron 4405
# ensemble nr 327
# cost tensor(0.8053, device='cuda:0')
# top n 253 0.893404483795166
# neuron 253
# ensemble nr 328
# cost tensor(0.8050, device='cuda:0')
# top n 2032 0.8931755423545837
# neuron 2032
# ensemble nr 329
# cost tensor(0.8047, device='cuda:0')
# top n 8875 0.8917909860610962
# neuron 8875
# ensemble nr 330
# cost tensor(0.8043, device='cuda:0')
# top n 108 0.9091364145278931
# neuron 108
# ensemble nr 331
# cost tensor(0.8039, device='cuda:0')
# top n 1067 0.8917484283447266
# neuron 1067
# ensemble nr 332
# cost tensor(0.8036, device='cuda:0')
# top n 4171 0.888891339302063
# neuron 4171
# ensemble nr 333
# cost tensor(0.8033, device='cuda:0')
# top n 7118 0.8874144554138184
# neuron 7118
# ensemble nr 334
# cost tensor(0.8029, device='cuda:0')
# top n 1326 0.8935953378677368
# neuron 1326
# ensemble nr 335
# cost tensor(0.8025, device='cuda:0')
# top n 2573 0.8876108527183533
# neuron 2573
# ensemble nr 336
# cost tensor(0.8021, device='cuda:0')
# top n 5677 0.8923665881156921
# neuron 5677
# ensemble nr 337
# cost tensor(0.8018, device='cuda:0')
# top n 1526 0.887042224407196
# neuron 1526
# ensemble nr 338
# cost tensor(0.8015, device='cuda:0')
# top n 1406 0.8948041796684265
# neuron 1406
# ensemble nr 339
# cost tensor(0.8011, device='cuda:0')
# top n 4494 0.8912003636360168
# neuron 4494
# ensemble nr 340
# cost tensor(0.8008, device='cuda:0')
# top n 453 0.8896932005882263
# neuron 453
# ensemble nr 341
# cost tensor(0.8004, device='cuda:0')
# top n 26 0.8897081613540649
# neuron 26
# ensemble nr 342
# cost tensor(0.8002, device='cuda:0')
# top n 1291 0.8847837448120117
# neuron 1291
# ensemble nr 343
# cost tensor(0.7999, device='cuda:0')
# top n 116 0.9010645151138306
# neuron 116
# ensemble nr 344
# cost tensor(0.7996, device='cuda:0')
# top n 194 0.8941877484321594
# neuron 194
# ensemble nr 345
# cost tensor(0.7993, device='cuda:0')
# top n 514 0.8957931399345398
# neuron 514
# ensemble nr 346
# cost tensor(0.7991, device='cuda:0')
# top n 1902 0.8887092471122742
# neuron 1902
# ensemble nr 347
# cost tensor(0.7987, device='cuda:0')
# top n 3214 0.8855580687522888
# neuron 3214
# ensemble nr 348
# cost tensor(0.7984, device='cuda:0')
# top n 742 1.0
# neuron 742
# ensemble nr 349
# cost tensor(0.7984, device='cuda:0')
# top n 182 0.8848922848701477
# neuron 182
# ensemble nr 350
# cost tensor(0.7981, device='cuda:0')
# top n 5215 1.0
# neuron 5215
# ensemble nr 351
# cost tensor(0.7981, device='cuda:0')
# top n 3434 0.8863757252693176
# neuron 3434
# ensemble nr 352
# cost tensor(0.7977, device='cuda:0')
# top n 6444 0.8981008529663086
# neuron 6444
# ensemble nr 353
# cost tensor(0.7973, device='cuda:0')
# top n 125 0.8969321250915527
# neuron 125
# ensemble nr 354
# cost tensor(0.7970, device='cuda:0')
# top n 304 0.9027355313301086
# neuron 304
# ensemble nr 355
# cost tensor(0.7966, device='cuda:0')
# top n 5215 1.0
# neuron 5215
# ensemble nr 356
# cost tensor(0.7966, device='cuda:0')
# top n 282 0.8965610861778259
# neuron 282
# ensemble nr 357
# cost tensor(0.7964, device='cuda:0')
# top n 499 0.8906934857368469
# neuron 499
# ensemble nr 358
# cost tensor(0.7961, device='cuda:0')
# top n 1739 0.8822957277297974
# neuron 1739
# ensemble nr 359
# cost tensor(0.7957, device='cuda:0')
# top n 1719 0.8826934695243835
# neuron 1719
# ensemble nr 360
# cost tensor(0.7955, device='cuda:0')
# top n 2212 0.8820826411247253
# neuron 2212
# ensemble nr 361
# cost tensor(0.7951, device='cuda:0')
# top n 5215 1.0
# neuron 5215
# ensemble nr 362
# cost tensor(0.7951, device='cuda:0')
# top n 9917 0.8898187875747681
# neuron 9917
# ensemble nr 363
# cost tensor(0.7948, device='cuda:0')
# top n 288 0.881210446357727
# neuron 288
# ensemble nr 364
# cost tensor(0.7945, device='cuda:0')
# top n 76 0.8826392292976379
# neuron 76
# ensemble nr 365
# cost tensor(0.7942, device='cuda:0')
# top n 1218 0.8838440179824829
# neuron 1218
# ensemble nr 366
# cost tensor(0.7938, device='cuda:0')
# top n 3919 0.8894428610801697
# neuron 3919
# ensemble nr 367
# cost tensor(0.7935, device='cuda:0')
# top n 1098 0.8996235728263855
# neuron 1098
# ensemble nr 368
# cost tensor(0.7932, device='cuda:0')
# top n 2117 0.8824403882026672
# neuron 2117
# ensemble nr 369
# cost tensor(0.7929, device='cuda:0')
# top n 7868 0.8840575218200684
# neuron 7868
# ensemble nr 370
# cost tensor(0.7926, device='cuda:0')
# top n 295 0.8955473899841309
# neuron 295
# ensemble nr 371
# cost tensor(0.7922, device='cuda:0')
# top n 2592 0.9259272813796997
# neuron 2592
# ensemble nr 372
# cost tensor(0.7919, device='cuda:0')
# top n 755 0.8793917894363403
# neuron 755
# ensemble nr 373
# cost tensor(0.7915, device='cuda:0')
# top n 3543 0.87971431016922
# neuron 3543
# ensemble nr 374
# cost tensor(0.7913, device='cuda:0')
# top n 5003 0.8921800851821899
# neuron 5003
# ensemble nr 375
# cost tensor(0.7909, device='cuda:0')
# top n 5215 1.0
# neuron 5215
# ensemble nr 376
# cost tensor(0.7909, device='cuda:0')
# top n 9055 0.8833276629447937
# neuron 9055
# ensemble nr 377
# cost tensor(0.7906, device='cuda:0')
# top n 4058 0.8792634010314941
# neuron 4058
# ensemble nr 378
# cost tensor(0.7902, device='cuda:0')
# top n 3712 0.8851683735847473
# neuron 3712
# ensemble nr 379
# cost tensor(0.7899, device='cuda:0')
# top n 4645 1.0
# neuron 4645
# ensemble nr 380
# cost tensor(0.7899, device='cuda:0')
# top n 3488 0.8803920745849609
# neuron 3488
# ensemble nr 381
# cost tensor(0.7896, device='cuda:0')
# top n 6463 0.8806220889091492
# neuron 6463
# ensemble nr 382
# cost tensor(0.7892, device='cuda:0')
# top n 1822 0.8853710293769836
# neuron 1822
# ensemble nr 383
# cost tensor(0.7889, device='cuda:0')
# top n 8162 0.8870380520820618
# neuron 8162
# ensemble nr 384
# cost tensor(0.7886, device='cuda:0')
# top n 4819 0.881521999835968
# neuron 4819
# ensemble nr 385
# cost tensor(0.7882, device='cuda:0')
# top n 475 0.8881227374076843
# neuron 475
# ensemble nr 386
# cost tensor(0.7879, device='cuda:0')
# top n 408 0.876987099647522
# neuron 408
# ensemble nr 387
# cost tensor(0.7876, device='cuda:0')
# top n 3322 0.889750599861145
# neuron 3322
# ensemble nr 388
# cost tensor(0.7873, device='cuda:0')
# top n 5443 0.8775488138198853
# neuron 5443
# ensemble nr 389
# cost tensor(0.7870, device='cuda:0')
# top n 8829 0.8972166180610657
# neuron 8829
# ensemble nr 390
# cost tensor(0.7866, device='cuda:0')
# top n 737 0.8938784599304199
# neuron 737
# ensemble nr 391
# cost tensor(0.7863, device='cuda:0')
# top n 249 0.9066801071166992
# neuron 249
# ensemble nr 392
# cost tensor(0.7860, device='cuda:0')
# top n 2141 0.8989070057868958
# neuron 2141
# ensemble nr 393
# cost tensor(0.7857, device='cuda:0')
# top n 6520 0.8822076916694641
# neuron 6520
# ensemble nr 394
# cost tensor(0.7854, device='cuda:0')
# top n 549 0.8790775537490845
# neuron 549
# ensemble nr 395
# cost tensor(0.7851, device='cuda:0')
# top n 2851 0.8752138018608093
# neuron 2851
# ensemble nr 396
# cost tensor(0.7848, device='cuda:0')
# top n 239 0.8893505930900574
# neuron 239
# ensemble nr 397
# cost tensor(0.7845, device='cuda:0')
# top n 7613 0.9008776545524597
# neuron 7613
# ensemble nr 398
# cost tensor(0.7841, device='cuda:0')
# top n 311 0.880618691444397
# neuron 311
# ensemble nr 399
# cost tensor(0.7838, device='cuda:0')
# top n 1198 0.8781185150146484
# neuron 1198
# ensemble nr 400
# cost tensor(0.7835, device='cuda:0')
# top n 5252 0.8811918497085571
# neuron 5252
# ensemble nr 401
# cost tensor(0.7833, device='cuda:0')
# top n 8973 0.9002618789672852
# neuron 8973
# ensemble nr 402
# cost tensor(0.7829, device='cuda:0')
# top n 3266 0.874032199382782
# neuron 3266
# ensemble nr 403
# cost tensor(0.7826, device='cuda:0')
# top n 2807 0.8749616742134094
# neuron 2807
# ensemble nr 404
# cost tensor(0.7823, device='cuda:0')
# top n 2930 0.8881969451904297
# neuron 2930
# ensemble nr 405
# cost tensor(0.7820, device='cuda:0')
# top n 884 0.8888193368911743
# neuron 884
# ensemble nr 406
# cost tensor(0.7817, device='cuda:0')
# top n 814 0.8760067224502563
# neuron 814
# ensemble nr 407
# cost tensor(0.7814, device='cuda:0')
# top n 5742 0.8748152852058411
# neuron 5742
# ensemble nr 408
# cost tensor(0.7811, device='cuda:0')
# top n 4877 0.8797089457511902
# neuron 4877
# ensemble nr 409
# cost tensor(0.7808, device='cuda:0')
# top n 124 0.8773183226585388
# neuron 124
# ensemble nr 410
# cost tensor(0.7805, device='cuda:0')
# top n 4083 0.8896452188491821
# neuron 4083
# ensemble nr 411
# cost tensor(0.7802, device='cuda:0')
# top n 9209 0.8929702043533325
# neuron 9209
# ensemble nr 412
# cost tensor(0.7799, device='cuda:0')
# top n 6458 0.877639889717102
# neuron 6458
# ensemble nr 413
# cost tensor(0.7797, device='cuda:0')
# top n 53 0.8815500140190125
# neuron 53
# ensemble nr 414
# cost tensor(0.7794, device='cuda:0')
# top n 4457 0.8937679529190063
# neuron 4457
# ensemble nr 415
# cost tensor(0.7791, device='cuda:0')
# top n 1525 0.8744179606437683
# neuron 1525
# ensemble nr 416
# cost tensor(0.7788, device='cuda:0')
# top n 5035 0.8861925005912781
# neuron 5035
# ensemble nr 417
# cost tensor(0.7784, device='cuda:0')
# top n 927 0.8729144930839539
# neuron 927
# ensemble nr 418
# cost tensor(0.7781, device='cuda:0')
# top n 813 0.8747881054878235
# neuron 813
# ensemble nr 419
# cost tensor(0.7778, device='cuda:0')
# top n 2831 0.8738061785697937
# neuron 2831
# ensemble nr 420
# cost tensor(0.7776, device='cuda:0')
# top n 10010 1.0
# neuron 10010
# ensemble nr 421
# cost tensor(0.7773, device='cuda:0')
# top n 10079 1.0
# neuron 10079
# ensemble nr 422
# cost tensor(0.7771, device='cuda:0')
# top n 10034 1.0
# neuron 10034
# ensemble nr 423
# cost tensor(0.7769, device='cuda:0')
# top n 10099 1.0
# neuron 10099
# ensemble nr 424
# cost tensor(0.7767, device='cuda:0')
# top n 10015 1.0
# neuron 10015
# ensemble nr 425
# cost tensor(0.7765, device='cuda:0')
# top n 10010 1.0
# neuron 10010
# ensemble nr 426
# cost tensor(0.7765, device='cuda:0')
# top n 10033 1.0
# neuron 10033
# ensemble nr 427
# cost tensor(0.7763, device='cuda:0')
# top n 10033 1.0
# neuron 10033
# ensemble nr 428
# cost tensor(0.7763, device='cuda:0')
# top n 10040 1.0
# neuron 10040
# ensemble nr 429
# cost tensor(0.7760, device='cuda:0')
# top n 10036 1.0
# neuron 10036
# ensemble nr 430
# cost tensor(0.7758, device='cuda:0')
# top n 10080 1.0
# neuron 10080
# ensemble nr 431
# cost tensor(0.7756, device='cuda:0')
# top n 10048 1.0
# neuron 10048
# ensemble nr 432
# cost tensor(0.7754, device='cuda:0')
# top n 10051 1.0
# neuron 10051
# ensemble nr 433
# cost tensor(0.7751, device='cuda:0')
# top n 10060 1.0
# neuron 10060
# ensemble nr 434
# cost tensor(0.7748, device='cuda:0')
# top n 10023 1.0
# neuron 10023
# ensemble nr 435
# cost tensor(0.7746, device='cuda:0')
# top n 10096 1.0
# neuron 10096
# ensemble nr 436
# cost tensor(0.7743, device='cuda:0')
# top n 10083 1.0
# neuron 10083
# ensemble nr 437
# cost tensor(0.7741, device='cuda:0')
# top n 10073 1.0
# neuron 10073
# ensemble nr 438
# cost tensor(0.7738, device='cuda:0')
# top n 10021 1.0
# neuron 10021
# ensemble nr 439
# cost tensor(0.7736, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 440
# cost tensor(0.7734, device='cuda:0')
# top n 10026 1.0
# neuron 10026
# ensemble nr 441
# cost tensor(0.7732, device='cuda:0')
# top n 10045 1.0
# neuron 10045
# ensemble nr 442
# cost tensor(0.7729, device='cuda:0')
# top n 10071 1.0
# neuron 10071
# ensemble nr 443
# cost tensor(0.7727, device='cuda:0')
# top n 10064 1.0
# neuron 10064
# ensemble nr 444
# cost tensor(0.7724, device='cuda:0')
# top n 10010 1.0
# neuron 10010
# ensemble nr 445
# cost tensor(0.7724, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 446
# cost tensor(0.7724, device='cuda:0')
# top n 10066 1.0
# neuron 10066
# ensemble nr 447
# cost tensor(0.7721, device='cuda:0')
# top n 10087 1.0
# neuron 10087
# ensemble nr 448
# cost tensor(0.7719, device='cuda:0')
# top n 10095 1.0
# neuron 10095
# ensemble nr 449
# cost tensor(0.7717, device='cuda:0')
# top n 10036 1.0
# neuron 10036
# ensemble nr 450
# cost tensor(0.7717, device='cuda:0')
# top n 10037 1.0
# neuron 10037
# ensemble nr 451
# cost tensor(0.7715, device='cuda:0')
# top n 10077 1.0
# neuron 10077
# ensemble nr 452
# cost tensor(0.7713, device='cuda:0')
# top n 10045 1.0
# neuron 10045
# ensemble nr 453
# cost tensor(0.7713, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 454
# cost tensor(0.7713, device='cuda:0')
# top n 10018 1.0
# neuron 10018
# ensemble nr 455
# cost tensor(0.7710, device='cuda:0')
# top n 10031 1.0
# neuron 10031
# ensemble nr 456
# cost tensor(0.7708, device='cuda:0')
# top n 10053 1.0
# neuron 10053
# ensemble nr 457
# cost tensor(0.7706, device='cuda:0')
# top n 10091 1.0
# neuron 10091
# ensemble nr 458
# cost tensor(0.7704, device='cuda:0')
# top n 10053 1.0
# neuron 10053
# ensemble nr 459
# cost tensor(0.7704, device='cuda:0')
# top n 10099 1.0
# neuron 10099
# ensemble nr 460
# cost tensor(0.7704, device='cuda:0')
# top n 10101 1.0
# neuron 10101
# ensemble nr 461
# cost tensor(0.7702, device='cuda:0')
# top n 10091 1.0
# neuron 10091
# ensemble nr 462
# cost tensor(0.7702, device='cuda:0')
# top n 10036 1.0
# neuron 10036
# ensemble nr 463
# cost tensor(0.7702, device='cuda:0')
# top n 10009 1.0
# neuron 10009
# ensemble nr 464
# cost tensor(0.7699, device='cuda:0')
# top n 10017 1.0
# neuron 10017
# ensemble nr 465
# cost tensor(0.7697, device='cuda:0')
# top n 10008 1.0
# neuron 10008
# ensemble nr 466
# cost tensor(0.7694, device='cuda:0')
# top n 10079 1.0
# neuron 10079
# ensemble nr 467
# cost tensor(0.7694, device='cuda:0')
# top n 10088 1.0
# neuron 10088
# ensemble nr 468
# cost tensor(0.7692, device='cuda:0')
# top n 10057 1.0
# neuron 10057
# ensemble nr 469
# cost tensor(0.7689, device='cuda:0')
# top n 10092 1.0
# neuron 10092
# ensemble nr 470
# cost tensor(0.7687, device='cuda:0')
# top n 10055 1.0
# neuron 10055
# ensemble nr 471
# cost tensor(0.7684, device='cuda:0')
# top n 10055 1.0
# neuron 10055
# ensemble nr 472
# cost tensor(0.7684, device='cuda:0')
# top n 10098 1.0
# neuron 10098
# ensemble nr 473
# cost tensor(0.7681, device='cuda:0')
# top n 10038 1.0
# neuron 10038
# ensemble nr 474
# cost tensor(0.7678, device='cuda:0')
# top n 10045 1.0
# neuron 10045
# ensemble nr 475
# cost tensor(0.7678, device='cuda:0')
# top n 10004 1.0
# neuron 10004
# ensemble nr 476
# cost tensor(0.7675, device='cuda:0')
# top n 10068 1.0
# neuron 10068
# ensemble nr 477
# cost tensor(0.7672, device='cuda:0')
# top n 10037 1.0
# neuron 10037
# ensemble nr 478
# cost tensor(0.7672, device='cuda:0')
# top n 10101 1.0
# neuron 10101
# ensemble nr 479
# cost tensor(0.7672, device='cuda:0')
# top n 10087 1.0
# neuron 10087
# ensemble nr 480
# cost tensor(0.7671, device='cuda:0')
# top n 10064 1.0
# neuron 10064
# ensemble nr 481
# cost tensor(0.7671, device='cuda:0')
# top n 10089 1.0
# neuron 10089
# ensemble nr 482
# cost tensor(0.7669, device='cuda:0')
# top n 10018 1.0
# neuron 10018
# ensemble nr 483
# cost tensor(0.7669, device='cuda:0')
# top n 10002 1.0
# neuron 10002
# ensemble nr 484
# cost tensor(0.7666, device='cuda:0')
# top n 10011 1.0
# neuron 10011
# ensemble nr 485
# cost tensor(0.7664, device='cuda:0')
# top n 10070 1.0
# neuron 10070
# ensemble nr 486
# cost tensor(0.7662, device='cuda:0')
# top n 10038 1.0
# neuron 10038
# ensemble nr 487
# cost tensor(0.7662, device='cuda:0')
# top n 10023 1.0
# neuron 10023
# ensemble nr 488
# cost tensor(0.7662, device='cuda:0')
# top n 10004 1.0
# neuron 10004
# ensemble nr 489
# cost tensor(0.7661, device='cuda:0')
# top n 10061 1.0
# neuron 10061
# ensemble nr 490
# cost tensor(0.7659, device='cuda:0')
# top n 10054 1.0
# neuron 10054
# ensemble nr 491
# cost tensor(0.7657, device='cuda:0')
# top n 10002 1.0
# neuron 10002
# ensemble nr 492
# cost tensor(0.7657, device='cuda:0')
# top n 10084 1.0
# neuron 10084
# ensemble nr 493
# cost tensor(0.7655, device='cuda:0')
# top n 10011 1.0
# neuron 10011
# ensemble nr 494
# cost tensor(0.7654, device='cuda:0')
# top n 10097 1.0
# neuron 10097
# ensemble nr 495
# cost tensor(0.7651, device='cuda:0')
# top n 10019 1.0
# neuron 10019
# ensemble nr 496
# cost tensor(0.7649, device='cuda:0')
# top n 10055 1.0
# neuron 10055
# ensemble nr 497
# cost tensor(0.7649, device='cuda:0')
# top n 10099 1.0
# neuron 10099
# ensemble nr 498
# cost tensor(0.7649, device='cuda:0')
# top n 10048 1.0
# neuron 10048
# ensemble nr 499
# cost tensor(0.7649, device='cuda:0')
# top n 10058 1.0
# neuron 10058
# ensemble nr 500
# cost tensor(0.7647, device='cuda:0')
# top n 10023 1.0
# neuron 10023
# ensemble nr 501
# cost tensor(0.7647, device='cuda:0')
# top n 10073 1.0
# neuron 10073
# ensemble nr 502
# cost tensor(0.7647, device='cuda:0')
# top n 10085 1.0
# neuron 10085
# ensemble nr 503
# cost tensor(0.7645, device='cuda:0')
# top n 10073 1.0
# neuron 10073
# ensemble nr 504
# cost tensor(0.7645, device='cuda:0')
# top n 10020 1.0
# neuron 10020
# ensemble nr 505
# cost tensor(0.7643, device='cuda:0')
# top n 10046 1.0
# neuron 10046
# ensemble nr 506
# cost tensor(0.7640, device='cuda:0')
# top n 10004 1.0
# neuron 10004
# ensemble nr 507
# cost tensor(0.7640, device='cuda:0')
# top n 10041 1.0
# neuron 10041
# ensemble nr 508
# cost tensor(0.7638, device='cuda:0')
# top n 10038 1.0
# neuron 10038
# ensemble nr 509
# cost tensor(0.7638, device='cuda:0')
# top n 10004 1.0
# neuron 10004
# ensemble nr 510
# cost tensor(0.7638, device='cuda:0')
# top n 10020 1.0
# neuron 10020
# ensemble nr 511
# cost tensor(0.7638, device='cuda:0')
# top n 10050 1.0
# neuron 10050
# ensemble nr 512
# cost tensor(0.7636, device='cuda:0')
# top n 10075 1.0
# neuron 10075
# ensemble nr 513
# cost tensor(0.7633, device='cuda:0')
# top n 10093 1.0
# neuron 10093
# ensemble nr 514
# cost tensor(0.7630, device='cuda:0')
# top n 10082 1.0
# neuron 10082
# ensemble nr 515
# cost tensor(0.7628, device='cuda:0')
# top n 10096 1.0
# neuron 10096
# ensemble nr 516
# cost tensor(0.7628, device='cuda:0')
# top n 10046 1.0
# neuron 10046
# ensemble nr 517
# cost tensor(0.7628, device='cuda:0')
# top n 10032 1.0
# neuron 10032
# ensemble nr 518
# cost tensor(0.7626, device='cuda:0')
# top n 10088 1.0
# neuron 10088
# ensemble nr 519
# cost tensor(0.7626, device='cuda:0')
# top n 10091 1.0
# neuron 10091
# ensemble nr 520
# cost tensor(0.7626, device='cuda:0')
# top n 10032 1.0
# neuron 10032
# ensemble nr 521
# cost tensor(0.7626, device='cuda:0')
# top n 10056 1.0
# neuron 10056
# ensemble nr 522
# cost tensor(0.7623, device='cuda:0')
# top n 10074 1.0
# neuron 10074
# ...
# neuron 10061
# ensemble nr 888
# cost tensor(inf, device='cuda:0')
# top n 10069 1.0
# neuron 10069
# ensemble nr 889
# cost tensor(inf, device='cuda:0')
# top n 10074 1.0
# neuron 10074
# ensemble nr 890
# cost tensor(inf, device='cuda:0')
# top n 10056 1.0
# neuron 10056
# ensemble nr 891
# cost tensor(inf, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 892
# cost tensor(inf, device='cuda:0')
# top n 10065 1.0
# neuron 10065
# ensemble nr 893
# cost tensor(inf, device='cuda:0')
# top n 10037 1.0
# neuron 10037
# ensemble nr 894
# cost tensor(inf, device='cuda:0')
# top n 10033 1.0
# neuron 10033
# ensemble nr 895
# cost tensor(inf, device='cuda:0')
# top n 10006 1.0
# neuron 10006
# ensemble nr 896
# cost tensor(inf, device='cuda:0')
# top n 10085 1.0
# neuron 10085
# ensemble nr 897
# cost tensor(inf, device='cuda:0')
# top n 10017 1.0
# neuron 10017
# ensemble nr 898
# cost tensor(inf, device='cuda:0')
# top n 10081 1.0
# neuron 10081
# ensemble nr 899
# cost tensor(inf, device='cuda:0')
# top n 10065 1.0
# neuron 10065
# ensemble nr 900
# cost tensor(inf, device='cuda:0')
# top n 10014 1.0
# neuron 10014
# ensemble nr 901
# cost tensor(inf, device='cuda:0')
# top n 10098 1.0
# neuron 10098
# ensemble nr 902
# cost tensor(inf, device='cuda:0')
# top n 10048 1.0
# neuron 10048
# ensemble nr 903
# cost tensor(inf, device='cuda:0')
# top n 10073 1.0
# neuron 10073
# ensemble nr 904
# cost tensor(inf, device='cuda:0')
# top n 10011 1.0
# neuron 10011
# ensemble nr 905
# cost tensor(inf, device='cuda:0')
# top n 10098 1.0
# neuron 10098
# ensemble nr 906
# cost tensor(inf, device='cuda:0')
# top n 10066 1.0
# neuron 10066
# ensemble nr 907
# cost tensor(inf, device='cuda:0')
# top n 10048 1.0
# neuron 10048
# ensemble nr 908
# cost tensor(inf, device='cuda:0')
# top n 10081 1.0
# neuron 10081
# ensemble nr 909
# cost tensor(inf, device='cuda:0')
# top n 10086 1.0
# neuron 10086
# ensemble nr 910
# cost tensor(inf, device='cuda:0')
# top n 10068 1.0
# neuron 10068
# ensemble nr 911
# cost tensor(inf, device='cuda:0')
# top n 10075 1.0
# neuron 10075
# ensemble nr 912
# cost tensor(inf, device='cuda:0')
# top n 10095 1.0
# neuron 10095
# ensemble nr 913
# cost tensor(inf, device='cuda:0')
# top n 10063 1.0
# neuron 10063
# ensemble nr 914
# cost tensor(inf, device='cuda:0')
# top n 10073 1.0
# neuron 10073
# ensemble nr 915
# cost tensor(inf, device='cuda:0')
# top n 10042 1.0
# neuron 10042
# ensemble nr 916
# cost tensor(inf, device='cuda:0')
# top n 10082 1.0
# neuron 10082
# ensemble nr 917
# cost tensor(inf, device='cuda:0')
# top n 10099 1.0
# neuron 10099
# ensemble nr 918
# cost tensor(inf, device='cuda:0')
# top n 10053 1.0
# neuron 10053
# ensemble nr 919
# cost tensor(inf, device='cuda:0')
# top n 10033 1.0
# neuron 10033
# ensemble nr 920
# cost tensor(inf, device='cuda:0')
# top n 10041 1.0
# neuron 10041
# ensemble nr 921
# cost tensor(inf, device='cuda:0')
# top n 10084 1.0
# neuron 10084
# ensemble nr 922
# cost tensor(inf, device='cuda:0')
# top n 10083 1.0
# neuron 10083
# ensemble nr 923
# cost tensor(inf, device='cuda:0')
# top n 10017 1.0
# neuron 10017
# ensemble nr 924
# cost tensor(inf, device='cuda:0')
# top n 10042 1.0
# neuron 10042
# ensemble nr 925
# cost tensor(inf, device='cuda:0')
# top n 10067 1.0
# neuron 10067
# ensemble nr 926
# cost tensor(inf, device='cuda:0')
# top n 10016 1.0
# neuron 10016
# ensemble nr 927
# cost tensor(inf, device='cuda:0')
# top n 10093 1.0
# neuron 10093
# ensemble nr 928
# cost tensor(inf, device='cuda:0')
# top n 10058 1.0
# neuron 10058
# ensemble nr 929
# cost tensor(inf, device='cuda:0')
# top n 10050 1.0
# neuron 10050
# ensemble nr 930
# cost tensor(inf, device='cuda:0')
# top n 10048 1.0
# neuron 10048
# ensemble nr 931
# cost tensor(inf, device='cuda:0')
# top n 10085 1.0
# neuron 10085
# ensemble nr 932
# cost tensor(inf, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 933
# cost tensor(inf, device='cuda:0')
# top n 10043 1.0
# neuron 10043
# ensemble nr 934
# cost tensor(inf, device='cuda:0')
# top n 10059 1.0
# neuron 10059
# ensemble nr 935
# cost tensor(inf, device='cuda:0')
# top n 10027 1.0
# neuron 10027
# ensemble nr 936
# cost tensor(inf, device='cuda:0')
# top n 10029 1.0
# neuron 10029
# ensemble nr 937
# cost tensor(inf, device='cuda:0')
# top n 10095 1.0
# neuron 10095
# ensemble nr 938
# cost tensor(inf, device='cuda:0')
# top n 10018 1.0
# neuron 10018
# ensemble nr 939
# cost tensor(inf, device='cuda:0')
# top n 10047 1.0
# neuron 10047
# ensemble nr 940
# cost tensor(inf, device='cuda:0')
# top n 10019 1.0
# neuron 10019
# ensemble nr 941
# cost tensor(inf, device='cuda:0')
# top n 10020 1.0
# neuron 10020
# ensemble nr 942
# cost tensor(inf, device='cuda:0')
# top n 10081 1.0
# neuron 10081
# ensemble nr 943
# cost tensor(inf, device='cuda:0')
# top n 10037 1.0
# neuron 10037
# ensemble nr 944
# cost tensor(inf, device='cuda:0')
# top n 10029 1.0
# neuron 10029
# ensemble nr 945
# cost tensor(inf, device='cuda:0')
# top n 10004 1.0
# neuron 10004
# ensemble nr 946
# cost tensor(inf, device='cuda:0')
# top n 10101 1.0
# neuron 10101
# ensemble nr 947
# cost tensor(inf, device='cuda:0')
# top n 10068 1.0
# neuron 10068
# ensemble nr 948
# cost tensor(inf, device='cuda:0')
# top n 10086 1.0
# neuron 10086
# ensemble nr 949
# cost tensor(inf, device='cuda:0')
# top n 10078 1.0
# neuron 10078
# ensemble nr 950
# cost tensor(inf, device='cuda:0')
# top n 10086 1.0
# neuron 10086
# ensemble nr 951
# cost tensor(inf, device='cuda:0')
# top n 10100 1.0
# neuron 10100
# ensemble nr 952
# cost tensor(inf, device='cuda:0')
# top n 10101 1.0
# neuron 10101
# ensemble nr 953
# cost tensor(inf, device='cuda:0')
# top n 10098 1.0
# neuron 10098
# ensemble nr 954
# cost tensor(inf, device='cuda:0')
# top n 10003 1.0
# neuron 10003
# ensemble nr 955
# cost tensor(inf, device='cuda:0')
# top n 10005 1.0
# neuron 10005
# ensemble nr 956
# cost tensor(inf, device='cuda:0')
# top n 10013 1.0
# neuron 10013
# ensemble nr 957
# cost tensor(inf, device='cuda:0')
# top n 10044 1.0
# neuron 10044
# ensemble nr 958
# cost tensor(inf, device='cuda:0')
# top n 10074 1.0
# neuron 10074
# ensemble nr 959
# cost tensor(inf, device='cuda:0')
# top n 10059 1.0
# neuron 10059
# ensemble nr 960
# cost tensor(inf, device='cuda:0')
# top n 10081 1.0
# neuron 10081
# ensemble nr 961
# cost tensor(inf, device='cuda:0')
# top n 10026 1.0
# neuron 10026
# ensemble nr 962
# cost tensor(inf, device='cuda:0')
# top n 10096 1.0
# neuron 10096
# ensemble nr 963
# cost tensor(inf, device='cuda:0')
# top n 10055 1.0
# neuron 10055
# ensemble nr 964
# cost tensor(inf, device='cuda:0')
# top n 10091 1.0
# neuron 10091
# ensemble nr 965
# cost tensor(inf, device='cuda:0')
# top n 10058 1.0
# neuron 10058
# ensemble nr 966
# cost tensor(inf, device='cuda:0')
# top n 10044 1.0
# neuron 10044
# ensemble nr 967
# cost tensor(inf, device='cuda:0')
# top n 10033 1.0
# neuron 10033
# ensemble nr 968
# cost tensor(inf, device='cuda:0')
# top n 10087 1.0
# neuron 10087
# ensemble nr 969
# cost tensor(inf, device='cuda:0')
# top n 10072 1.0
# neuron 10072
# ensemble nr 970
# cost tensor(inf, device='cuda:0')
# top n 10054 1.0
# neuron 10054
# ensemble nr 971
# cost tensor(inf, device='cuda:0')
# top n 10021 1.0
# neuron 10021
# ensemble nr 972
# cost tensor(inf, device='cuda:0')
# top n 10089 1.0
# neuron 10089
# ensemble nr 973
# cost tensor(inf, device='cuda:0')
# top n 10065 1.0
# neuron 10065
# ensemble nr 974
# cost tensor(inf, device='cuda:0')
# top n 10014 1.0
# neuron 10014
# ensemble nr 975
# cost tensor(inf, device='cuda:0')
# top n 10006 1.0
# neuron 10006
# ensemble nr 976
# cost tensor(inf, device='cuda:0')
# top n 10069 1.0
# neuron 10069
# ensemble nr 977
# cost tensor(inf, device='cuda:0')
# top n 10022 1.0
# neuron 10022
# ensemble nr 978
# cost tensor(inf, device='cuda:0')
# top n 10015 1.0
# neuron 10015
# ensemble nr 979
# cost tensor(inf, device='cuda:0')
# top n 10074 1.0
# neuron 10074
# ensemble nr 980
# cost tensor(inf, device='cuda:0')
# top n 10036 1.0
# neuron 10036
# ensemble nr 981
# cost tensor(inf, device='cuda:0')
# top n 10092 1.0
# neuron 10092
# ensemble nr 982
# cost tensor(inf, device='cuda:0')
# top n 10049 1.0
# neuron 10049
# ensemble nr 983
# cost tensor(inf, device='cuda:0')
# top n 10055 1.0
# neuron 10055
# ensemble nr 984
# cost tensor(inf, device='cuda:0')
# top n 10054 1.0
# neuron 10054
# ensemble nr 985
# cost tensor(inf, device='cuda:0')
# top n 10043 1.0
# neuron 10043
# ensemble nr 986
# cost tensor(inf, device='cuda:0')
# top n 10077 1.0
# neuron 10077
# ensemble nr 987
# cost tensor(inf, device='cuda:0')
# top n 10062 1.0
# neuron 10062
# ensemble nr 988
# cost tensor(inf, device='cuda:0')
# top n 10084 1.0
# neuron 10084
# ensemble nr 989
# cost tensor(inf, device='cuda:0')
# top n 10083 1.0
# neuron 10083
# ensemble nr 990
# cost tensor(inf, device='cuda:0')
# top n 10034 1.0
# neuron 10034
# ensemble nr 991
# cost tensor(inf, device='cuda:0')
# top n 10051 1.0
# neuron 10051
# ensemble nr 992
# cost tensor(inf, device='cuda:0')
# top n 10039 1.0
# neuron 10039
# ensemble nr 993
# cost tensor(inf, device='cuda:0')
# top n 10041 1.0
# neuron 10041
# ensemble nr 994
# cost tensor(inf, device='cuda:0')
# top n 10025 1.0
# neuron 10025
# ensemble nr 995
# cost tensor(inf, device='cuda:0')
# top n 10089 1.0
# neuron 10089
# ensemble nr 996
# cost tensor(inf, device='cuda:0')
# top n 10041 1.0
# neuron 10041
# ensemble nr 997
# cost tensor(inf, device='cuda:0')
# top n 10098 1.0
# neuron 10098
# ensemble nr 998
# cost tensor(inf, device='cuda:0')
# top n 10023 1.0
# neuron 10023
# ensemble nr 999
# cost tensor(inf, device='cuda:0')
# torch.Size([5880, 10103])
# torch.Size([10103, 1000])
# torch.Size([1000, 5880])
# 1549.1372239589691
# [13, 75, 30, 11, 108, 73, 86, 96, 10, 98, 124, 59, 47, 101, 38, 5, 26, 40, 28, 36, 71, 45, 72, 38, 6, 26, 16, 13, 16, 12, 22, 4, 20, 26, 6, 8, 13, 11, 18, 32, 14, 3, 17, 12, 8, 10, 10, 17, 4, 8, 5, 5, 15, 12, 7, 4, 6, 4, 7, 4, 12, 6, 15, 4, 4, 7, 6, 4, 9, 4, 5, 14, 15, 10, 4, 7, 4, 6, 6, 4, 7, 14, 4, 3, 3, 6, 8, 4, 6, 3, 13, 5, 3, 8, 9, 6, 7, 7, 3, 5, 4, 10, 5, 3, 4, 3, 4, 4, 4, 12, 4, 5, 9, 7, 7, 4, 4, 3, 3, 4, 4, 3, 7, 6, 3, 5, 6, 3, 4, 3, 4, 4, 5, 3, 3, 3, 3, 4, 4, 3, 3, 6, 4, 3, 3, 3, 3, 3, 3, 4, 5, 4, 2, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 4, 4, 2, 4, 2, 3, 3, 4, 3, 4, 3, 4, 4, 3, 3, 3, 4, 3, 5, 6, 3, 3, 3, 3, 4, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 4, 3, 3, 3, 4, 3, 3, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# [0.9982824325561523, 0.9963696002960205, 0.9941439628601074, 0.9927192330360413, 0.9911258816719055, 0.9895303249359131, 0.9878196120262146, 0.9859920144081116, 0.9850263595581055, 0.9829850792884827, 0.9817823171615601, 0.9803496599197388, 0.9790198802947998, 0.9779569506645203, 0.9761350154876709, 0.9753220081329346, 0.9742573499679565, 0.9733306169509888, 0.9719133973121643, 0.9709821343421936, 0.9699944257736206, 0.9685727953910828, 0.9676171541213989, 0.9658456444740295, 0.9648119211196899, 0.9627698063850403, 0.9613226056098938, 0.9602527618408203, 0.9590389728546143, 0.9578099250793457, 0.9567760825157166, 0.9555740356445312, 0.9547910690307617, 0.9536538124084473, 0.9525590538978577, 0.9515566229820251, 0.9505396485328674, 0.9495843052864075, 0.9485046863555908, 0.9470175504684448, 0.946317732334137, 0.9453694224357605, 0.9446707367897034, 0.9431850910186768, 0.9419169425964355, 0.9411942362785339, 0.939854085445404, 0.9388293623924255, 0.93813157081604, 0.9373646974563599, 0.9364272952079773, 0.9355950951576233, 0.934540867805481, 0.9337598085403442, 0.933148980140686, 0.9325621724128723, 0.9321233034133911, 0.9312826991081238, 0.9301472306251526, 0.9294087290763855, 0.9285212755203247, 0.9275010228157043, 0.9264642596244812, 0.9259131550788879, 0.9253134727478027, 0.9244900345802307, 0.923531711101532, 0.9229341745376587, 0.9222469329833984, 0.9217801094055176, 0.9211432337760925, 0.920397937297821, 0.9197898507118225, 0.9189213514328003, 0.9185124635696411, 0.9177755117416382, 0.9172613024711609, 0.9165794849395752, 0.9158238768577576, 0.9153871536254883, 0.9149687886238098, 0.9142555594444275, 0.9135564565658569, 0.9127329587936401, 0.9123029708862305, 0.9114998579025269, 0.9109449982643127, 0.9103494882583618, 0.9097824096679688, 0.909038245677948, 0.90826815366745, 0.9078662395477295, 0.9073126316070557, 0.9067078232765198, 0.9059568643569946, 0.9054180383682251, 0.9048818349838257, 0.9040422439575195, 0.9036766886711121, 0.9028942584991455, 0.9022765755653381, 0.9016151428222656, 0.9011988639831543, 0.9005416035652161, 0.8999831080436707, 0.8993832468986511, 0.898898720741272, 0.8982319831848145, 0.8977221250534058, 0.8970299363136292, 0.8963576555252075, 0.8954854607582092, 0.8948556780815125, 0.8943778872489929, 0.8936367630958557, 0.8932830691337585, 0.8926345705986023, 0.8920958042144775, 0.8914473056793213, 0.8910519480705261, 0.8905772566795349, 0.8899484872817993, 0.8889565467834473, 0.8885681629180908, 0.888105571269989, 0.8874510526657104, 0.8869779109954834, 0.8863552808761597, 0.8858257532119751, 0.8851954936981201, 0.8846878409385681, 0.884056568145752, 0.8832179307937622, 0.8826954364776611, 0.8822203278541565, 0.8815843462944031, 0.8810476660728455, 0.8803526163101196, 0.8796647191047668, 0.8791188597679138, 0.878658652305603, 0.8780332207679749, 0.8774598240852356, 0.8769128322601318, 0.8764286041259766, 0.875953197479248, 0.8754225969314575, 0.874763548374176, 0.8740963935852051, 0.8736028075218201, 0.8730741739273071, 0.872672975063324, 0.8723101615905762, 0.871826708316803, 0.8714099526405334, 0.8709757328033447, 0.8705258369445801, 0.8700581192970276, 0.869651734828949, 0.8691168427467346, 0.8684748411178589, 0.8681219816207886, 0.8677201271057129, 0.8673860430717468, 0.8668813109397888, 0.8665114045143127, 0.8659908771514893, 0.8655716776847839, 0.865155816078186, 0.8646529912948608, 0.8642337918281555, 0.8637872338294983, 0.8634225130081177, 0.8630698919296265, 0.8627294898033142, 0.862282931804657, 0.8618618845939636, 0.8614006042480469, 0.8610200881958008, 0.8605856895446777, 0.8601781129837036, 0.8598296046257019, 0.8594232201576233, 0.8590378761291504, 0.8586381077766418, 0.8582667112350464, 0.8578301072120667, 0.8573797345161438, 0.8569858074188232, 0.8566673994064331, 0.8562232851982117, 0.8557368516921997, 0.8552150726318359, 0.8547877669334412, 0.8544110059738159, 0.8544110059738159, 0.854069709777832, 0.8536897897720337, 0.8533297181129456, 0.8528139591217041, 0.8524705767631531, 0. ...

# %%
def test_train_split(data,stim):
    unique, counts = np.unique(stim.flatten(), return_counts=True)
    count_dict=dict(zip(unique, counts))

    keys_with_enough_data=[]
    for key in count_dict.keys():
        if count_dict[key]==2:
            keys_with_enough_data.append(key)

    filtered_stims=np.isin(stim.flatten(),keys_with_enough_data)

    #Arrange data so that responses with the same stimulus are adjacent
    z=stim.flatten()[np.where(filtered_stims)[0]]
    sortd=np.argsort(z)
    istim=np.sort(z)
    X=data[filtered_stims,:]
    out=X[sortd,:].copy()

    x_train=out[::2,:]
    y_train=istim[::2]
    x_test=out[1::2,:]
    y_test=istim[1::2]
    
    return x_train, x_test, y_train, y_test

def evaluate_model(x_train,x_test):
    corr_mat=np.zeros((x_train.shape[0],x_train.shape[0]))
    for j in range(0,x_train.shape[0]):
        for i in range(0,x_test.shape[0]):
            corr_mat[j,i]=np.corrcoef(x_train[j,:],x_test[i,:])[0,1]
    print(np.mean(np.argmax(corr_mat, axis=0) == np.arange(0,x_train.shape[0],1,int)))
    
stim=sio.loadmat('/home/maria/Documents/EnsemblePursuit/data/natimg2800_M170717_MP034_2017-09-11.mat')['stim']['istim'][0][0]
x_train, x_test, y_train, y_test=test_train_split(np.array(V.t()),stim)
evaluate_model(x_train,x_test)
# Out:
# /home/maria/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3103: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-75adea428453> in <module>()
#      33 stim=sio.loadmat('/home/maria/Documents/EnsemblePursuit/data/natimg2800_M170717_MP034_2017-09-11.mat')['stim']['istim'][0][0]
#      34 x_train, x_test, y_train, y_test=test_train_split(np.array(V.t()),stim)
# ---> 35 evaluate_model(x_train,x_test)
#
# <ipython-input-5-75adea428453> in evaluate_model(x_train, x_test)
#      28     for j in range(0,x_train.shape[0]):
#      29         for i in range(0,x_test.shape[0]):
# ---> 30             corr_mat[j,i]=np.corrcoef(x_train[j,:],x_test[i,:])[0,1]
#      31     print(np.mean(np.argmax(corr_mat, axis=0) == np.arange(0,x_train.shape[0],1,int)))
#      32
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    3173         warnings.warn('bias and ddof have no effect and are deprecated',
#    3174                       DeprecationWarning, stacklevel=2)
# -> 3175     c = cov(x, y, rowvar)
#    3176     try:
#    3177         d = diag(c)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    3101         fact = 0.0
#    3102
# -> 3103     X -= avg[:, None]
#    3104     if w is None:
#    3105         X_T = X.T
#
# KeyboardInterrupt:

# %%
x_train, x_test, y_train, y_test=test_train_split(X[:,seed_neurons],stim)
evaluate_model(x_train,x_test)

# %%
print(len(seed_neurons))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(nr_of_neurons)
plt.title('Histogram of assembly sizes, lambda 500, 1000 assemblies')
