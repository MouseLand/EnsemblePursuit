# %%
import SingleMousePipeline as mp

# %%
data_path='/home/maria/Documents/EnsemblePursuit/SAND9/data/'
mouse_filename='natimg2800_M170717_MP034_2017-09-11.mat'
ep_numpy_model=mp.ModelPipelineSingleMouse(data_path=data_path,mouse_filename=mouse_filename,model='EnsemblePursuit_numpy',nr_of_components=50,lambd_=0.01)
U,V=ep_numpy_model.fit_model()
ep_numpy_model.knn(V)
assembly_array=ep_numpy_model.fit_ridge(V)
ep_numpy_model.plot_all_receptive_fields(assembly_array)
ep_numpy_model.variance_explained_across_neurons(U,V)
# Out:
# nr of neurons in ensemble 1432
# ensemble nr 0
# cost 0.9940062256834048
# nr of neurons in ensemble 2253
# ensemble nr 1
# cost 0.9881546625858167
# nr of neurons in ensemble 997
# ensemble nr 2
# cost 0.984965870303595
# nr of neurons in ensemble 798
# ensemble nr 3
# cost 0.982469943379388
# nr of neurons in ensemble 556
# ensemble nr 4
# cost 0.9805514115400218
# nr of neurons in ensemble 765
# ensemble nr 5
# cost 0.978395033404176
# nr of neurons in ensemble 636
# ensemble nr 6
# cost 0.9762967131783268
# nr of neurons in ensemble 637
# ensemble nr 7
# cost 0.9745114872780317
# nr of neurons in ensemble 656
# ensemble nr 8
# cost 0.9725498690147336
# nr of neurons in ensemble 603
# ensemble nr 9
# cost 0.9707187075842345
# nr of neurons in ensemble 512
# ensemble nr 10
# cost 0.9692603414589872
# nr of neurons in ensemble 498
# ensemble nr 11
# cost 0.9679004632161833
# nr of neurons in ensemble 445
# ensemble nr 12
# cost 0.9665257087633703
# nr of neurons in ensemble 391
# ensemble nr 13
# cost 0.9653176098585383
# nr of neurons in ensemble 342
# ensemble nr 14
# cost 0.9641498696737016
# nr of neurons in ensemble 389
# ensemble nr 15
# cost 0.9628923491368426
# nr of neurons in ensemble 283
# ensemble nr 16
# cost 0.9619367846811043
# nr of neurons in ensemble 396
# ensemble nr 17
# cost 0.960757788138543
# nr of neurons in ensemble 224
# ensemble nr 18
# cost 0.9598996265069006
# nr of neurons in ensemble 284
# ensemble nr 19
# cost 0.9589718218792717
# nr of neurons in ensemble 328
# ensemble nr 20
# cost 0.958025492837388
# nr of neurons in ensemble 304
# ensemble nr 21
# cost 0.9571769632003158
# nr of neurons in ensemble 299
# ensemble nr 22
# cost 0.9562557807550618
# nr of neurons in ensemble 327
# ensemble nr 23
# cost 0.9553146923916033
# nr of neurons in ensemble 359
# ensemble nr 24
# cost 0.954359946868346
# nr of neurons in ensemble 209
# ensemble nr 25
# cost 0.9535910286278315
# nr of neurons in ensemble 204
# ensemble nr 26
# cost 0.9527910028898731
# nr of neurons in ensemble 338
# ensemble nr 27
# cost 0.9516590449919686
# nr of neurons in ensemble 424
# ensemble nr 28
# cost 0.9507083954445136
# nr of neurons in ensemble 207
# ensemble nr 29
# cost 0.9499676387520406
# nr of neurons in ensemble 207
# ensemble nr 30
# cost 0.9492326415847473
# nr of neurons in ensemble 266
# ensemble nr 31
# cost 0.9484662166013694
# nr of neurons in ensemble 219
# ensemble nr 32
# cost 0.9477362176511536
# nr of neurons in ensemble 288
# ensemble nr 33
# cost 0.9469732882035453
# nr of neurons in ensemble 150
# ensemble nr 34
# cost 0.9463070812255483
# nr of neurons in ensemble 305
# ensemble nr 35
# cost 0.9454655683707857
# nr of neurons in ensemble 202
# ensemble nr 36
# cost 0.9447933620651455
# nr of neurons in ensemble 190
# ensemble nr 37
# cost 0.9442042633943197
# nr of neurons in ensemble 159
# ensemble nr 38
# cost 0.9435981688659467
# nr of neurons in ensemble 267
# ensemble nr 39
# cost 0.9428293832958948
# nr of neurons in ensemble 159
# ensemble nr 40
# cost 0.9421831763216939
# nr of neurons in ensemble 214
# ensemble nr 41
# cost 0.9414807018893404
# nr of neurons in ensemble 228
# ensemble nr 42
# cost 0.9408375636090822
# nr of neurons in ensemble 74
# ensemble nr 43
# cost 0.9404080555580968
# nr of neurons in ensemble 210
# ensemble nr 44
# cost 0.9397426308554085
# nr of neurons in ensemble 133
# ensemble nr 45
# cost 0.9391836836672365
# nr of neurons in ensemble 201
# ensemble nr 46
# cost 0.9386037359071138
# nr of neurons in ensemble 144
# ensemble nr 47
# cost 0.9380981139497381
# nr of neurons in ensemble 94
# ensemble nr 48
# cost 0.9376645258697097
# nr of neurons in ensemble 145
# ensemble nr 49
# cost 0.9371155362564061
# Time 630.4984481334686
# (2800, 2800)
#                                 Experiment  accuracy
# 0  natimg2800_M170717_MP034_2017-09-11.mat  0.352857
# torch.Size([2800, 18360])
# torch.Size([2800, 2800])
# Total variance explained, averaged over neurons is: 0.06260789575132386

# %%
print(U.shape,V.shape)
# Out:
# (10103, 50) (5880, 50)
