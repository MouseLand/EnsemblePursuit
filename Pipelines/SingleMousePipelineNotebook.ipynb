# %%
import SingleMousePipeline as mp

# %%
data_path='/home/maria/Documents/EnsemblePursuit/SAND9/data/'
mouse_filename='natimg2800_M170717_MP034_2017-09-11.mat'
ep_numpy_model=mp.ModelPipelineSingleMouse(data_path=data_path,mouse_filename=mouse_filename,model='EnsemblePursuit_numpy',nr_of_components=2,lambd_=0.01)
U,V=ep_numpy_model.fit_model()
#ep_numpy_model.knn(V)
#assembly_array=ep_numpy_model.fit_ridge(V)
#ep_numpy_model.plot_all_receptive_fields(assembly_array)
ep_numpy_model.variance_explained_across_neurons(U,V)
# Out:
# /home/maria/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:138: RuntimeWarning: invalid value encountered in sqrt
#   ret = um.sqrt(ret, out=ret)
# ensemble nr 0
# cost 0.9940062256834048
# ensemble nr 1
# cost 0.9881546625858167
# Time 23.97494101524353
# Total variance explained, averaged over neurons is: 0.01159142013730996

# %%
print(U.shape,V.shape)
