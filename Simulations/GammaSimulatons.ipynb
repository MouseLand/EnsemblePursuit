# %%
from GammaSimulations import GammaSimulations

# %%
#PCA initialization
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='NMF'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)
# Out:
# torch.Size([150, 5800])
# torch.Size([10000, 150])
# Epoch number: 0
# Current loss: 4.3374090668950316e-14
# Epoch number: 1
# Current loss: 4.3374063563896004e-14
# Epoch number: 2
# Current loss: 4.337407372829137e-14
# Epoch number: 3
# Current loss: 4.337404662323706e-14
# Epoch number: 4
# Current loss: 4.337394836741518e-14
# Epoch number: 5
# Current loss: 4.337392803862444e-14
# Epoch number: 6
# Current loss: 4.3374087280818527e-14
# Epoch number: 7
# Current loss: 4.3374405765206694e-14
# Epoch number: 8
# Current loss: 4.337438204828417e-14
# Epoch number: 9
# Current loss: 4.337400596565559e-14
# Epoch number: 10
# Current loss: 4.337411438587284e-14
# Epoch number: 11
# Current loss: 4.3373992413128434e-14
# Epoch number: 12
# Current loss: 4.337351468654618e-14
# Epoch number: 13
# Current loss: 4.3372955644800995e-14
# Epoch number: 14
# Current loss: 4.3372989526118885e-14
# Epoch number: 15
# Current loss: 4.3372745580630076e-14
# Epoch number: 16
# ...

# %%
#NMF initialization
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='NMF'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)
# Out:
# torch.Size([150, 5800])
# torch.Size([10000, 150])
# Epoch number: 0
# Current loss: 0.4493081569671631
# Epoch number: 1
# Current loss: 0.4491076171398163
# Epoch number: 2
# Current loss: 0.4487282335758209
# Epoch number: 3
# Current loss: 0.44819095730781555
# Epoch number: 4
# Current loss: 0.447515606880188
# Epoch number: 5
# Current loss: 0.4467208981513977
# Epoch number: 6
# Current loss: 0.44582420587539673
# Epoch number: 7
# Current loss: 0.4448416531085968
# Epoch number: 8
# Current loss: 0.44378796219825745
# Epoch number: 9
# Current loss: 0.4426765441894531
# Epoch number: 10
# Current loss: 0.44151946902275085
# Epoch number: 11
# Current loss: 0.44032758474349976
# Epoch number: 12
# Current loss: 0.43911054730415344
# Epoch number: 13
# Current loss: 0.4378768503665924
# Epoch number: 14
# Current loss: 0.4366339445114136
# Epoch number: 15
# Current loss: 0.43538835644721985
# Epoch number: 16
# Current loss: 0.43414556980133057
# Epoch number: 17
# ...

# %%
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='NMF'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)

# %%
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='NMF'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)

# %%
print(sim.V.shape)

# %%
print(sim.V_orig.shape)

# %%
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='EnsemblePursuitNumpy'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)
#X=sim.simulate_data(nr_components,nr_timepoints,nr_neurons)
#X_noise=sim.simulate_data_w_noise(nr_components,nr_timepoints,nr_neurons,noise_ampl_mult=4)

# %%
print(X.shape)
import matplotlib.pyplot as plt
plt.plot(X[0,:])
