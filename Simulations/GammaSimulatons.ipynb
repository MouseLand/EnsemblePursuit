# %%
from GammaSimulations import GammaSimulations

# %%
nr_components=150
nr_timepoints=5800
nr_neurons=10000
model_string='EnsemblePursuitNumpy'
sim=GammaSimulations()
sim.run_and_fit(model_string,nr_components,nr_timepoints,nr_neurons,lambd=0.01)
sim.V_corr_mat(model_string)
sim.variance_explained_across_neurons()
sim.sparsity(model_string,nr_components)
#X=sim.simulate_data(nr_components,nr_timepoints,nr_neurons)
#X_noise=sim.simulate_data_w_noise(nr_components,nr_timepoints,nr_neurons,noise_ampl_mult=4)
# Out:
# nr of neurons in ensemble 93
# ensemble nr 0
# cost 0.7692494256926653
# nr of neurons in ensemble 91
# ensemble nr 1
# cost 0.7638281877089813
# nr of neurons in ensemble 93
# ensemble nr 2
# cost 0.7589949127042153
# nr of neurons in ensemble 98
# ensemble nr 3
# cost 0.7534692225401164
# nr of neurons in ensemble 94
# ensemble nr 4
# cost 0.7489122266580021
# nr of neurons in ensemble 119
# ensemble nr 5
# cost 0.7424052444459271
# nr of neurons in ensemble 102
# ensemble nr 6
# cost 0.7371171844834545
# nr of neurons in ensemble 108
# ensemble nr 7
# cost 0.7320274905177523
# nr of neurons in ensemble 91
# ensemble nr 8
# cost 0.7269178366632281
# nr of neurons in ensemble 110
# ensemble nr 9
# cost 0.7206993757610557
# nr of neurons in ensemble 113
# ensemble nr 10
# cost 0.7143220857599815
# nr of neurons in ensemble 105
# ensemble nr 11
# cost 0.7092360220094103
# nr of neurons in ensemble 104
# ensemble nr 12
# cost 0.7038757387447117
# nr of neurons in ensemble 97
# ensemble nr 13
# cost 0.6991832459860975
# nr of neurons in ensemble 84
# ensemble nr 14
# cost 0.6944715172717711
# nr of neurons in ensemble 90
# ensemble nr 15
# cost 0.6893754953733158
# nr of neurons in ensemble 91
# ensemble nr 16
# cost 0.6843840300308566
# nr of neurons in ensemble 116
# ensemble nr 17
# cost 0.6786208234542178
# nr of neurons in ensemble 96
# ensemble nr 18
# cost 0.6739958875501549
# nr of neurons in ensemble 100
# ensemble nr 19
# cost 0.6678823439703435
# nr of neurons in ensemble 85
# ensemble nr 20
# cost 0.66297799204876
# nr of neurons in ensemble 105
# ensemble nr 21
# cost 0.6573748495600462
# nr of neurons in ensemble 69
# ensemble nr 22
# cost 0.6540284761240287
# nr of neurons in ensemble 98
# ensemble nr 23
# cost 0.6489535627414007
# nr of neurons in ensemble 103
# ensemble nr 24
# cost 0.6432174323681066
# nr of neurons in ensemble 95
# ensemble nr 25
# cost 0.6381777468794821
# nr of neurons in ensemble 105
# ensemble nr 26
# cost 0.6331616273479657
# nr of neurons in ensemble 95
# ensemble nr 27
# cost 0.6281851203331843
# nr of neurons in ensemble 104
# ensemble nr 28
# cost 0.6226460618081529
# nr of neurons in ensemble 104
# ensemble nr 29
# cost 0.6168271229817813
# nr of neurons in ensemble 105
# ensemble nr 30
# cost 0.6106393516278694
# nr of neurons in ensemble 101
# ensemble nr 31
# cost 0.6053756857369156
# nr of neurons in ensemble 98
# ensemble nr 32
# cost 0.5995100788370842
# nr of neurons in ensemble 105
# ensemble nr 33
# cost 0.5936221369738442
# nr of neurons in ensemble 111
# ensemble nr 34
# cost 0.5880262118671377
# nr of neurons in ensemble 92
# ensemble nr 35
# cost 0.5836534732081727
# nr of neurons in ensemble 97
# ensemble nr 36
# cost 0.5781537313254164
# nr of neurons in ensemble 106
# ensemble nr 37
# cost 0.5725639617385155
# nr of neurons in ensemble 109
# ensemble nr 38
# cost 0.5665410331074084
# nr of neurons in ensemble 88
# ensemble nr 39
# cost 0.5617064643285872
# nr of neurons in ensemble 100
# ensemble nr 40
# cost 0.5568102584260564
# nr of neurons in ensemble 93
# ensemble nr 41
# cost 0.5520178916856688
# nr of neurons in ensemble 92
# ensemble nr 42
# cost 0.547792419238025
# nr of neurons in ensemble 105
# ensemble nr 43
# cost 0.542840830236831
# nr of neurons in ensemble 110
# ensemble nr 44
# cost 0.5371173999572791
# nr of neurons in ensemble 95
# ensemble nr 45
# cost 0.5315149033220924
# nr of neurons in ensemble 96
# ensemble nr 46
# cost 0.5263218914818908
# nr of neurons in ensemble 98
# ensemble nr 47
# cost 0.5211175229125008
# nr of neurons in ensemble 96
# ensemble nr 48
# cost 0.5165402071193737
# nr of neurons in ensemble 115
# ensemble nr 49
# cost 0.5109183898549874
# nr of neurons in ensemble 81
# ensemble nr 50
# cost 0.5061711946675238
# nr of neurons in ensemble 97
# ensemble nr 51
# cost 0.5013286854293937
# nr of neurons in ensemble 110
# ensemble nr 52
# cost 0.49526467129251434
# nr of neurons in ensemble 93
# ensemble nr 53
# cost 0.4903159538464941
# nr of neurons in ensemble 88
# ensemble nr 54
# cost 0.48592797554040473
# nr of neurons in ensemble 86
# ensemble nr 55
# cost 0.4814006666181935
# nr of neurons in ensemble 108
# ensemble nr 56
# cost 0.4758181706570966
# nr of neurons in ensemble 91
# ensemble nr 57
# cost 0.4714979447984371
# nr of neurons in ensemble 95
# ensemble nr 58
# cost 0.4665043256591013
# nr of neurons in ensemble 111
# ensemble nr 59
# cost 0.4610456984810811
# nr of neurons in ensemble 107
# ensemble nr 60
# cost 0.455837248585533
# nr of neurons in ensemble 97
# ensemble nr 61
# cost 0.4513256068000914
# nr of neurons in ensemble 96
# ensemble nr 62
# cost 0.4464490129049204
# nr of neurons in ensemble 86
# ensemble nr 63
# cost 0.44165750891945504
# nr of neurons in ensemble 109
# ensemble nr 64
# cost 0.43651565487978716
# nr of neurons in ensemble 101
# ensemble nr 65
# cost 0.43130510237816533
# nr of neurons in ensemble 117
# ensemble nr 66
# cost 0.42552348242066584
# nr of neurons in ensemble 98
# ensemble nr 67
# cost 0.4203959766909498
# nr of neurons in ensemble 108
# ensemble nr 68
# cost 0.41530222063553124
# nr of neurons in ensemble 99
# ensemble nr 69
# cost 0.4105430906710627
# nr of neurons in ensemble 113
# ensemble nr 70
# cost 0.40531152832282596
# nr of neurons in ensemble 87
# ensemble nr 71
# cost 0.40065710281499367
# nr of neurons in ensemble 100
# ensemble nr 72
# cost 0.39594854168538274
# nr of neurons in ensemble 103
# ensemble nr 73
# cost 0.39003951760009997
# nr of neurons in ensemble 103
# ensemble nr 74
# cost 0.38456988110823875
# nr of neurons in ensemble 91
# ensemble nr 75
# cost 0.3805415664083782
# nr of neurons in ensemble 88
# ensemble nr 76
# cost 0.3759059499630438
# nr of neurons in ensemble 106
# ensemble nr 77
# cost 0.3704939601645095
# nr of neurons in ensemble 104
# ensemble nr 78
# cost 0.36494811111089676
# nr of neurons in ensemble 96
# ensemble nr 79
# cost 0.3600232475501479
# nr of neurons in ensemble 96
# ensemble nr 80
# cost 0.3551154780677863
# nr of neurons in ensemble 91
# ensemble nr 81
# cost 0.3504936187338086
# nr of neurons in ensemble 120
# ensemble nr 82
# cost 0.34413272524129096
# nr of neurons in ensemble 98
# ensemble nr 83
# cost 0.3394335887841636
# nr of neurons in ensemble 110
# ensemble nr 84
# cost 0.33385590593271447
# nr of neurons in ensemble 104
# ensemble nr 85
# cost 0.32876514827876546
# nr of neurons in ensemble 80
# ensemble nr 86
# cost 0.3243588042613067
# nr of neurons in ensemble 99
# ensemble nr 87
# cost 0.31990769251082135
# nr of neurons in ensemble 95
# ensemble nr 88
# cost 0.31555053609753897
# nr of neurons in ensemble 85
# ensemble nr 89
# cost 0.310706104232145
# nr of neurons in ensemble 86
# ensemble nr 90
# cost 0.30654230155149553
# nr of neurons in ensemble 113
# ensemble nr 91
# cost 0.300927377157717
# nr of neurons in ensemble 107
# ensemble nr 92
# cost 0.29567053512874575
# nr of neurons in ensemble 119
# ensemble nr 93
# cost 0.28938918197728786
# nr of neurons in ensemble 99
# ensemble nr 94
# cost 0.2845877848635007
# nr of neurons in ensemble 97
# ensemble nr 95
# cost 0.27938589651561846
# nr of neurons in ensemble 101
# ensemble nr 96
# cost 0.2741806625772598
# nr of neurons in ensemble 112
# ensemble nr 97
# cost 0.26902547561528317
# nr of neurons in ensemble 107
# ensemble nr 98
# cost 0.2629750368619206
# nr of neurons in ensemble 106
# ensemble nr 99
# cost 0.2572242267072161
# nr of neurons in ensemble 105
# ensemble nr 100
# cost 0.2515872026842749
# nr of neurons in ensemble 96
# ensemble nr 101
# cost 0.2468346410268565
# nr of neurons in ensemble 103
# ensemble nr 102
# cost 0.24178390670041947
# nr of neurons in ensemble 111
# ensemble nr 103
# cost 0.2360470585731199
# nr of neurons in ensemble 107
# ensemble nr 104
# cost 0.23036372746181646
# nr of neurons in ensemble 91
# ensemble nr 105
# cost 0.2258036011190409
# nr of neurons in ensemble 87
# ensemble nr 106
# cost 0.22153570851299975
# nr of neurons in ensemble 102
# ensemble nr 107
# cost 0.2168908537776743
# nr of neurons in ensemble 96
# ensemble nr 108
# cost 0.21131611075964826
# nr of neurons in ensemble 99
# ensemble nr 109
# cost 0.20628774684074586
# nr of neurons in ensemble 108
# ensemble nr 110
# cost 0.20101910242647691
# nr of neurons in ensemble 91
# ensemble nr 111
# cost 0.19636881220682562
# nr of neurons in ensemble 104
# ensemble nr 112
# cost 0.19070094975475851
# nr of neurons in ensemble 102
# ensemble nr 113
# cost 0.18575530215525798
# nr of neurons in ensemble 97
# ensemble nr 114
# cost 0.1808903663633112
# nr of neurons in ensemble 98
# ensemble nr 115
# cost 0.17579098407037644
# nr of neurons in ensemble 103
# ensemble nr 116
# cost 0.17072489017614764
# nr of neurons in ensemble 101
# ensemble nr 117
# cost 0.1650969575631698
# nr of neurons in ensemble 98
# ensemble nr 118
# cost 0.16033526652809973
# nr of neurons in ensemble 98
# ensemble nr 119
# cost 0.15588384036755357
# nr of neurons in ensemble 115
# ensemble nr 120
# cost 0.15045573189697925
# nr of neurons in ensemble 105
# ensemble nr 121
# cost 0.14553288623473207
# nr of neurons in ensemble 93
# ensemble nr 122
# cost 0.14108569408143046
# nr of neurons in ensemble 110
# ensemble nr 123
# cost 0.1358584207864823
# nr of neurons in ensemble 93
# ensemble nr 124
# cost 0.13153134107337133
# nr of neurons in ensemble 99
# ensemble nr 125
# cost 0.12620052266716403
# nr of neurons in ensemble 94
# ensemble nr 126
# cost 0.12172510061048239
# nr of neurons in ensemble 111
# ensemble nr 127
# cost 0.11634526192159482
# nr of neurons in ensemble 95
# ensemble nr 128
# cost 0.11154436052322529
# nr of neurons in ensemble 100
# ensemble nr 129
# cost 0.10651623131015202
# nr of neurons in ensemble 89
# ensemble nr 130
# cost 0.10253743532510684
# nr of neurons in ensemble 105
# ensemble nr 131
# cost 0.09697932386971209
# nr of neurons in ensemble 100
# ensemble nr 132
# cost 0.09182752583715469
# nr of neurons in ensemble 105
# ensemble nr 133
# cost 0.08629488863618487
# nr of neurons in ensemble 97
# ensemble nr 134
# cost 0.08127391703350216
# nr of neurons in ensemble 99
# ensemble nr 135
# cost 0.0762399890797521
# nr of neurons in ensemble 114
# ensemble nr 136
# cost 0.07059366752335718
# nr of neurons in ensemble 112
# ensemble nr 137
# cost 0.06473520318683362
# nr of neurons in ensemble 82
# ensemble nr 138
# cost 0.06054539240170922
# nr of neurons in ensemble 116
# ensemble nr 139
# cost 0.05458004725555351
# nr of neurons in ensemble 101
# ensemble nr 140
# cost 0.0497939305287621
# nr of neurons in ensemble 90
# ensemble nr 141
# cost 0.04550257748298332
# nr of neurons in ensemble 115
# ensemble nr 142
# cost 0.039701134855604996
# nr of neurons in ensemble 93
# ensemble nr 143
# cost 0.03520997735950776
# nr of neurons in ensemble 95
# ensemble nr 144
# cost 0.03094686847127946
# nr of neurons in ensemble 120
# ensemble nr 145
# cost 0.025114806169199907
# nr of neurons in ensemble 98
# ensemble nr 146
# cost 0.020213015469773755
# nr of neurons in ensemble 93
# ensemble nr 147
# cost 0.015208350999370863
# nr of neurons in ensemble 94
# ensemble nr 148
# cost 0.010224693754939654
# nr of neurons in ensemble 81
# ensemble nr 149
# cost 0.006690519300831733
# /home/maria/Documents/EnsemblePursuit/Simulations/GammaSimulations.py:70: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax1=plt.subplot(2,3,1)
# [0.04637959 0.04753684 0.05988189 0.05050637 0.05035032 0.04330099
#  0.04160777 0.04755058 0.05108157 0.04521814 0.05988189 0.05653359
#  0.06930559 0.05732068 0.05610371 0.04719818 0.05610371 0.05721833
#  0.06060358 0.05498926 0.04637959 0.04822149 0.05165232 0.05132212
#  0.06930559 0.05035032 0.05280353 0.04253181 0.05722011 0.0583821
#  0.05332764 0.04694348 0.055349   0.047512   0.05001354 0.05492301
#  0.05653359 0.04321534 0.04702999 0.04090309 0.05409226 0.03637804
#  0.05492937 0.05498926 0.05075228 0.03683851 0.0384044  0.03422581
#  0.04466386 0.05061614 0.04772854 0.04164736 0.04317812 0.05492301
#  0.06118253 0.05722011 0.04177094 0.05699535 0.04894584 0.03684298
#  0.05050637 0.04894584 0.04998307 0.03657096 0.0453315  0.04226556
#  0.05555583 0.04934415 0.03544485 0.06118253 0.04034212 0.04441006
#  0.05721833 0.0461663  0.04520725 0.03953314 0.0449833  0.04364287
#  0.05156545 0.0499368  0.05005533 0.03984356 0.04753684 0.04213697
#  0.04954046 0.06060358 0.04132876 0.05379313 0.04853573 0.04164818
#  0.05116651 0.04702999 0.03841933 0.03998505 0.03836806 0.050179
