# %%
from Simulations import Simulations

# %%
nr_components=25
nr_timepoints=50
nr_neurons=50
sim=Simulations()
sim.run_and_fit('PCA',nr_components,nr_timepoints,nr_neurons)
sim.V_corr_mat('PCA')
sim.find_nearest_V_comp('PCA')
# Out:
# SHPS (50, 25) (25, 50)
# orig (50, 50)
# approx (50, 50)
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# [1.15752475e-16 1.44320156e-16 6.32367695e-16 6.32367695e-16
#  4.13529323e-16 4.98562616e-16 4.98562616e-16 4.90644325e-16
#  8.45917877e-16 2.11915494e-16 4.90644325e-16 8.45917877e-16
#  2.67118458e-16 1.38926333e-16 5.65249244e-16 5.65249244e-16
#  2.81094663e-16 7.52045899e-16 7.52045899e-16 6.38688095e-16
#  8.80121857e-16 2.59186807e-16 5.24840738e-16 8.80121857e-16
#  3.52833384e-16]
# [0.28958703 0.59710694 0.50989143 0.49827295 0.45674891 0.38591669
# ...

# %%
nr_components=25
nr_timepoints=50
nr_neurons=50
lambd=0.01
sim=Simulations()
sim.run_and_fit('EnsemblePursuit',nr_components,nr_timepoints,nr_neurons,lambd)
nn=sim.find_nearest_U_comp('EnsemblePursuit',2)
sim.plot_nn(2,nr_timepoints)
sim.plot_recovered_U(3)
sim.check_orthogonality()
sim.neuron_corrs()
sim.find_and_plot_all_nearest_U()
sim.V_corr_mat('EnsemblePursuit')
sim.find_nearest_V_comp('EnsemblePursuit')
print(sim.variance_explained_one_component(1))
print(sim.total_variance_explained())
#sim.find_nearest_V_comp()
# Out:
# ensemble nr 0
# cost tensor(0.7358, device='cuda:0')
# ensemble nr 1
# cost tensor(0.6860, device='cuda:0')
# ensemble nr 2
# cost tensor(0.6339, device='cuda:0')
# ensemble nr 3
# cost tensor(0.5862, device='cuda:0')
# ensemble nr 4
# cost tensor(0.5326, device='cuda:0')
# ensemble nr 5
# cost tensor(0.4884, device='cuda:0')
# ensemble nr 6
# cost tensor(0.4417, device='cuda:0')
# ensemble nr 7
# cost tensor(0.4013, device='cuda:0')
# ensemble nr 8
# cost tensor(0.3661, device='cuda:0')
# ensemble nr 9
# cost tensor(0.3330, device='cuda:0')
# ensemble nr 10
# cost tensor(0.2978, device='cuda:0')
# ensemble nr 11
# cost tensor(0.2653, device='cuda:0')
# ensemble nr 12
# cost tensor(0.2435, device='cuda:0')
# ensemble nr 13
# cost tensor(0.2240, device='cuda:0')
# ensemble nr 14
# cost tensor(0.2089, device='cuda:0')
# ensemble nr 15
# cost tensor(0.1927, device='cuda:0')
# ensemble nr 16
# cost tensor(0.1798, device='cuda:0')
# ensemble nr 17
# cost tensor(0.1666, device='cuda:0')
# ...

# %%
print(sim.variance_explained_one_component(16))
print(sim.variance_explained_by_neuron())
# Out:
# [-0.          0.         -0.         ... -0.24459668  0.779371
#   0.8690025 ]
# 0.012976308615646581
# (50, 50)
# (50, 50)
# ...

# %%
sim=Simulations()
sim.run_and_fit("ICA",nr_components,nr_timepoints,nr_neurons,lambd)
nn=sim.find_nearest_U_comp('ICA',2)
sim.find_nearest_U_comp('ICA',2)
sim.plot_nn(3,nr_timepoints)
sim.plot_recovered_U(3)
sim.check_orthogonality()
sim.neuron_corrs()
sim.find_and_plot_all_nearest_U()
sim.find_nearest_V_comp('ICA')
# Out:
# (50, 25)
# (25, 50)
# SHPS (50, 25) (25, 50)
# orig (50, 50)
# approx (50, 50)
# arg 6
# arg 6
# orth [[ 17.21816351  -1.18349276  -3.27199531 ... -10.68342681  -4.51349929
#    -7.95624782]
#  [ -1.18349276  24.90856287   4.50570551 ...   3.97728213  -2.16216326
#     2.71308155]
#  [ -3.27199531   4.50570551  23.76588114 ...  -0.42094218 -12.04199761
#     6.09115502]
#  ...
#  [-10.68342681   3.97728213  -0.42094218 ...  22.15529611  -1.86461704
#     2.60400878]
#  [ -4.51349929  -2.16216326 -12.04199761 ...  -1.86461704  35.48330252
#     3.11524795]
#  [ -7.95624782   2.71308155   6.09115502 ...   2.60400878   3.11524795
#    21.15430178]]
# [19, 14, 6, 6, 13, 14, 14, 19, 19, 14, 19, 14, 14, 19, 14, 19, 14, 19, 14, 14, 14, 19, 19, 14, 19]
# ...

# %%
sim.V_corr_mat('ICA')
# Out:
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# [2.41242014e-15 2.38710745e-15 5.26466101e-15 1.08137033e-15
#  2.59534378e-15 2.08507557e-15 2.85019849e-15 4.73643619e-15
#  3.18824894e-15 3.43136311e-15 3.04955955e-15 4.28836589e-15
#  5.26466101e-15 3.72292476e-15 2.49742622e-15 3.04955955e-15
#  3.27429852e-15 2.59534378e-15 5.65548213e-15 2.09323348e-15
#  4.73643619e-15 2.49742622e-15 1.26841120e-15 2.00907804e-15
#  5.65548213e-15]
# [0.27316423 0.29227432 0.30564255 0.37286294 0.32242081 0.46776087
# ...

# %%
print(sim.total_variance_explained())
# Out:
# 1.0
