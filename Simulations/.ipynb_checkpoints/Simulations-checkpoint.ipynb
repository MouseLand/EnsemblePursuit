# %%
from Simulations import Simulations

# %%
nr_components=25
nr_timepoints=200
nr_neurons=50
lambd=0.01
sim=Simulations()
sim.run_and_fit('EnsemblePursuit',nr_components,nr_timepoints,nr_neurons,lambd)
nn=sim.find_nearest_U_comp('EnsemblePursuit',2)
sim.plot_nn(2,nr_timepoints)
sim.plot_recovered_U(3)
sim.check_orthogonality()
sim.neuron_corrs()
sim.find_and_plot_all_nearest_U()
sim.V_corr_mat('EnsemblePursuit')
# Out:
# ensemble nr 0
# cost tensor(0.7692, device='cuda:0')
# ensemble nr 1
# cost tensor(0.7217, device='cuda:0')
# ensemble nr 2
# cost tensor(0.6765, device='cuda:0')
# ensemble nr 3
# cost tensor(0.6313, device='cuda:0')
# ensemble nr 4
# cost tensor(0.5795, device='cuda:0')
# ensemble nr 5
# cost tensor(0.5336, device='cuda:0')
# ensemble nr 6
# cost tensor(0.4904, device='cuda:0')
# ensemble nr 7
# cost tensor(0.4514, device='cuda:0')
# ensemble nr 8
# cost tensor(0.4142, device='cuda:0')
# ensemble nr 9
# cost tensor(0.3863, device='cuda:0')
# ensemble nr 10
# cost tensor(0.3563, device='cuda:0')
# ensemble nr 11
# cost tensor(0.3315, device='cuda:0')
# ensemble nr 12
# cost tensor(0.3004, device='cuda:0')
# ensemble nr 13
# cost tensor(0.2792, device='cuda:0')
# ensemble nr 14
# cost tensor(0.2591, device='cuda:0')
# ensemble nr 15
# cost tensor(0.2353, device='cuda:0')
# ensemble nr 16
# cost tensor(0.2148, device='cuda:0')
# ensemble nr 17
# cost tensor(0.1980, device='cuda:0')
# ensemble nr 18
# cost tensor(0.1805, device='cuda:0')
# ensemble nr 19
# cost tensor(0.1655, device='cuda:0')
# ensemble nr 20
# cost tensor(0.1533, device='cuda:0')
# ensemble nr 21
# cost tensor(0.1448, device='cuda:0')
# ensemble nr 22
# cost tensor(0.1346, device='cuda:0')
# ensemble nr 23
# cost tensor(0.1266, device='cuda:0')
# ensemble nr 24
# cost tensor(0.1173, device='cuda:0')
# (50, 25)
# (25, 200)
# SHPS (50, 25) (25, 200)
# orig (50, 200)
# approx (50, 200)
# arg 17
# orth [[27.11471011  3.73646217 -3.1007393  ...  4.09351628  0.2431802
#   -6.90941956]
#  [ 3.73646217 28.98319634  1.76479304 ...  3.2654473   2.38762771
#   -6.78986689]
#  [-3.1007393   1.76479304 25.54275539 ... -0.36106133 -2.33821131
#   -0.68450714]
#  ...
#  [ 4.09351628  3.2654473  -0.36106133 ... 16.55479549  4.66999642
#    4.60653499]
#  [ 0.2431802   2.38762771 -2.33821131 ...  4.66999642 20.51061304
#   -5.14724887]
#  [-6.90941956 -6.78986689 -0.68450714 ...  4.60653499 -5.14724887
#   39.1228467 ]]
# [13, 8, 17, 5, 6, 9, 14, 6, 15, 10, 12, 3, 12, 1, 4, 2, 10, 2, 3, 11, 14, 2, 3, 19, 6]
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
sim=Simulations()
sim.run_and_fit("ICA",nr_components,nr_timepoints,nr_neurons,lambd)
nn=sim.find_nearest_U_comp('ICA',2)
sim.find_nearest_U_comp('ICA',2)
sim.plot_nn(3,nr_timepoints)
sim.plot_recovered_U(3)
sim.check_orthogonality()
sim.neuron_corrs()
sim.find_and_plot_all_nearest_U()
# Out:
# boyaka
# (50, 25)
# (25, 200)
# SHPS (50, 25) (25, 200)
# orig (50, 200)
# approx (50, 200)
# arg 15
# /home/maria/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/fastica_.py:118: UserWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn('FastICA did not converge. Consider increasing '
# arg 15
# orth [[27.11471011  3.73646217 -3.1007393  ...  4.09351628  0.2431802
#   -6.90941956]
#  [ 3.73646217 28.98319634  1.76479304 ...  3.2654473   2.38762771
#   -6.78986689]
#  [-3.1007393   1.76479304 25.54275539 ... -0.36106133 -2.33821131
#   -0.68450714]
#  ...
#  [ 4.09351628  3.2654473  -0.36106133 ... 16.55479549  4.66999642
#    4.60653499]
#  [ 0.2431802   2.38762771 -2.33821131 ...  4.66999642 20.51061304
#   -5.14724887]
#  [-6.90941956 -6.78986689 -0.68450714 ...  4.60653499 -5.14724887
#   39.1228467 ]]
# [2, 8, 15, 2, 2, 3, 2, 2, 2, 10, 2, 21, 2, 4, 2, 2, 2, 2, 14, 2, 2, 2, 21, 20, 14]

# %%
sim.V_corr_mat('ICA')
# Out:
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /home/maria/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
