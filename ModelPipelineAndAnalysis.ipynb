# %%
from SAND9ModelPipeline import ModelPipeline

# %%
data_path='/home/maria/Documents/EnsemblePursuit/SAND9/data/'
save_path='/home/maria/Documents/EnsemblePursuit/SAND9/experiments/'

# %%
ica=ModelPipeline(data_path=data_path, save_path=save_path, model='ICA',nr_of_components=150)
#ica.fit_model()

# %%
ica.knn()
# Out:
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/
# (2800, 2800)
# (2366, 2366)
# (1779, 1779)
# (2590, 2590)
# (2800, 2800)
# (2800, 2800)
# (1755, 1755)
#                                           Experiment  accuracy
# 0  natimg2800_M170604_MP031_2017-06-28.mat_V_ICA.npy  0.302500
# 1  natimg2800_M160825_MP027_2016-12-14.mat_V_ICA.npy  0.360947
# 2  natimg2800_M170717_MP033_2017-08-20.mat_V_ICA.npy  0.696459
# 3  natimg2800_M161025_MP030_2017-05-29.mat_V_ICA.npy  0.276448
# 4  natimg2800_M170714_MP032_2017-08-07.mat_V_ICA.npy  0.183214
# 5  natimg2800_M170717_MP034_2017-09-11.mat_V_ICA.npy  0.539643
# 6  natimg2800_M170714_MP032_2017-09-14.mat_V_ICA.npy  0.369801
#        accuracy
# count  7.000000
# mean   0.389859
# std    0.173624
# min    0.183214
# 25%    0.289474
# 50%    0.360947
# 75%    0.454722
# max    0.696459
#                                           Experiment  accuracy
# 0  natimg2800_M170604_MP031_2017-06-28.mat_V_ICA.npy  0.302500
# ...

# %%
ica.fit_ridge()
# Out:
# torch.Size([2800, 18360])
# torch.Size([2800, 2800])
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170604_MP031_2017-06-28.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M160825_MP027_2016-12-14.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP033_2017-08-20.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M161025_MP030_2017-05-29.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170714_MP032_2017-08-07.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP034_2017-09-11.mat_V_ICA.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170714_MP032_2017-09-14.mat_V_ICA.npy

# %%
ica.plot_all_receptive_fields()
# Out:
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M160825_MP027_2016-12-14.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170714_MP032_2017-08-07.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170714_MP032_2017-09-14.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP033_2017-08-20.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M161025_MP030_2017-05-29.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170604_MP031_2017-06-28.mat_ica_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP034_2017-09-11.mat_ica_reg.npy

# %%
spca=ModelPipeline(data_path=data_path, save_path=save_path, model='SparsePCA',nr_of_components=150)
spca.fit_model()
# Out:
# natimg2800_M170717_MP034_2017-09-11.mat
# /home/maria/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:138: RuntimeWarning: invalid value encountered in sqrt
#   ret = um.sqrt(ret, out=ret)
# [dict_learning] ..
# /home/maria/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 54 iterations, alpha=3.744e-04, previous alpha=3.744e-04, with an active set of 55 regressors.
#   ConvergenceWarning)
# /home/maria/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/least_angle.py:339: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 52 iterations, alpha=4.699e-04, previous alpha=4.699e-04, with an active set of 53 regressors.
#   ConvergenceWarning)
# .
# ...
