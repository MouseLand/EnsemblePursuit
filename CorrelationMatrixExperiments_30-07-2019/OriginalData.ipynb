# %%
from SAND9ModelPipeline import ModelPipeline

# %%
data_path='/home/maria/Documents/EnsemblePursuit/SAND9/data/'
save_path='/home/maria/Documents/EnsemblePursuit/SAND9/experiments/'

# %%
ep=ModelPipeline(data_path=data_path,save_path=save_path,model='EnsemblePursuit_adaptive',nr_of_components=150)
ep.fit_model()
# Out:
# natimg2800_M161025_MP030_2017-05-29.mat
# 0.09196288883686066
# ensemble nr 0
# cost tensor(0.9991, device='cuda:0')
# 0.08794911950826645
# ensemble nr 1
# cost tensor(0.9984, device='cuda:0')
# 0.10924375802278519
# ensemble nr 2
# cost tensor(0.9977, device='cuda:0')
# 0.07285097241401672
# ensemble nr 3
# cost tensor(0.9971, device='cuda:0')
# 0.07980754226446152
# ensemble nr 4
# cost tensor(0.9965, device='cuda:0')
# 0.07256484776735306
# ensemble nr 5
# cost tensor(0.9957, device='cuda:0')
# 0.0555197112262249
# ensemble nr 6
# cost tensor(0.9950, device='cuda:0')
# 0.06838863343000412
# ensemble nr 7
# cost tensor(0.9945, device='cuda:0')
# 0.05549667030572891
# ensemble nr 8
# cost tensor(0.9937, device='cuda:0')
# 0.05260757729411125
# ensemble nr 9
# cost tensor(0.9933, device='cuda:0')
# 0.04899267107248306
# ensemble nr 10
# cost tensor(0.9925, device='cuda:0')
# 0.050729140639305115
# ensemble nr 11
# cost tensor(0.9919, device='cuda:0')
# 0.0514533706009388
# ...

# %%
ep.knn()
# Out:
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/
# (2800, 2800)
# (2590, 2590)
# (2800, 2800)
# (1779, 1779)
# (2800, 2800)
# (2366, 2366)
# (1755, 1755)
#                                                   Experiment  accuracy
# 0  natimg2800_M170717_MP034_2017-09-11.mat_V_ep_adaptive.npy  0.407143
# 1  natimg2800_M161025_MP030_2017-05-29.mat_V_ep_adaptive.npy  0.190347
# 2  natimg2800_M170714_MP032_2017-08-07.mat_V_ep_adaptive.npy  0.116786
# 3  natimg2800_M170717_MP033_2017-08-20.mat_V_ep_adaptive.npy  0.379427
# 4  natimg2800_M170604_MP031_2017-06-28.mat_V_ep_adaptive.npy  0.197500
# 5  natimg2800_M160825_MP027_2016-12-14.mat_V_ep_adaptive.npy  0.175824
# 6  natimg2800_M170714_MP032_2017-09-14.mat_V_ep_adaptive.npy  0.244444
#        accuracy
# count  7.000000
# mean   0.244496
# std    0.108648
# min    0.116786
# 25%    0.183086
# 50%    0.197500
# 75%    0.311936
# max    0.407143
#                                                   Experiment  accuracy
# ...

# %%
ep.check_sparsity()

# %%
ep.fit_ridge()
# Out:
# torch.Size([2800, 18360])
# torch.Size([2800, 2800])
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP034_2017-09-11.mat_V_ep_adaptive.npy

# %%
ep.plot_all_receptive_fields()
# Out:
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP034_2017-09-11.mat*_ep_adaptive_reg.npy
# /home/maria/Documents/EnsemblePursuit/SAND9/experiments/natimg2800_M170717_MP034_2017-09-11.mat_ep_adaptive_reg.npy
