# %%
from Simulations import Simulations

# %%
nr_components=100
nr_timepoints=5000
nr_neurons=10000
sim=Simulations()
sim.run_and_fit('EnsemblePursuit',nr_components,nr_timepoints,nr_neurons,lambd=0)
sim.target_corr_vs_nr_neurons()
# Out:
# 0.0026289448142051697
# ensemble nr 0
# cost tensor(0.6270, device='cuda:0')
# 0.0024288753047585487
# ensemble nr 1
# cost tensor(0.6266, device='cuda:0')
# 0.0024116244167089462
# ensemble nr 2
# cost tensor(0.6263, device='cuda:0')
# 0.0023051851894706488
# ensemble nr 3
# cost tensor(0.6259, device='cuda:0')
# 0.0026855426840484142
# ensemble nr 4
# cost tensor(0.6256, device='cuda:0')
# 0.0023012161254882812
# ensemble nr 5
# cost tensor(0.6253, device='cuda:0')
# 0.00248315860517323
# ensemble nr 6
# cost tensor(0.6249, device='cuda:0')
# 0.0024554640986025333
# ensemble nr 7
# cost tensor(0.6245, device='cuda:0')
# 0.0025678991805762053
# ensemble nr 8
# cost tensor(0.6242, device='cuda:0')
# 0.0028205609414726496
# ensemble nr 9
# cost tensor(0.6238, device='cuda:0')
# 0.0028757648542523384
# ensemble nr 10
# cost tensor(0.6235, device='cuda:0')
# 0.0024698032066226006
# ensemble nr 11
# cost tensor(0.6231, device='cuda:0')
# 0.0024644460063427687
# ensemble nr 12
# ...
